# %%
# !pip install pycryptodome psutil memory-profiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pycryptodome in c:\users\bruno\appdata\roaming\python\python312\site-packages (3.20.0)
# Requirement already satisfied: psutil in d:\anaconda3\lib\site-packages (5.9.0)
# Collecting memory-profiler
#   Using cached memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Using cached memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory-profiler
# Successfully installed memory-profiler-0.61.0
#   WARNING: The script mprof.exe is installed in 'C:\Users\bruno\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para criptografar um texto com Kyber
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Realiza a encapsulação (criptografia) usando a chave pública
    shared_secret, ciphertext = kem_encaps512(pub_key)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext (hex): {safe_hexlify(ciphertext)}")

    # Retorna as chaves e ciphertext
    return priv_key, pub_key, ciphertext

# Função para descriptografar o texto com Kyber
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_hex = input("Digite o Ciphertext em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext = unhexlify(ciphertext_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext)

    # Apresenta a chave secreta compartilhada (Shared Secret)
    print("\n===== Descriptografia Completa =====")
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber")
    print("2: Descriptografar um texto usando Kyber")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber
# 2: Descriptografar um texto usando Kyber
# Digite o número da opção desejada:  1
# === Criptografar ===
# ===== Criptografia Completa =====
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 8441c02b04b46ef7b580d2a69964dd095d8d53c53560b677e643db1e107dbed6
# Ciphertext (hex): ...

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para criptografar um texto com Kyber
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Realiza a encapsulação (criptografia) usando a chave pública
    shared_secret, ciphertext = kem_encaps512(pub_key)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext (hex): {safe_hexlify(ciphertext)}")

    # Retorna as chaves e ciphertext
    return priv_key, pub_key, ciphertext

# Função para descriptografar o texto com Kyber
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_hex = input("Digite o Ciphertext em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext = unhexlify(ciphertext_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext)

    # Apresenta a chave secreta compartilhada (Shared Secret)
    print("\n===== Descriptografia Completa =====")
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber")
    print("2: Descriptografar um texto usando Kyber")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber
# 2: Descriptografar um texto usando Kyber
# Digite o número da opção desejada:  2
# === Descriptografar ===
# Digite a Private Key em hex:  ...
# Digite o Ciphertext em hex:  ...
# ===== Descriptografia Completa =====
# Shared Secret Decapsulado (hex): 08c3995d5c23b87ad624335a1fd820fd6f37090f04530c559379f221dde28579

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para criptografar um texto com Kyber
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Entrada do texto pelo usuário
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    # Realiza a encapsulação (criptografia) usando a chave pública
    shared_secret, ciphertext = kem_encaps512(pub_key)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext (hex): {safe_hexlify(ciphertext)}")

    # Retorna as chaves e ciphertext
    return priv_key, pub_key, ciphertext, plaintext

# Função para descriptografar o texto com Kyber
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_hex = input("Digite o Ciphertext em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext = unhexlify(ciphertext_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext)

    # Apresenta a chave secreta compartilhada (Shared Secret)
    print("\n===== Descriptografia Completa =====")
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber")
    print("2: Descriptografar um texto usando Kyber")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber
# 2: Descriptografar um texto usando Kyber
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  Teste
# ===== Criptografia Completa =====
# Texto original: Teste
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 68ec4211d7cc54b24023cfa912d5f19f8cb0037a264f27cb717f43bc494a9cd4
# Ciphertext (hex): ...

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para criptografar um texto com Kyber
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Entrada do texto pelo usuário
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    # Realiza a encapsulação (criptografia) usando a chave pública
    shared_secret, ciphertext = kem_encaps512(pub_key)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext (hex): {safe_hexlify(ciphertext)}")

    # Retorna as chaves e ciphertext
    return priv_key, pub_key, ciphertext, plaintext

# Função para descriptografar o texto com Kyber
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_hex = input("Digite o Ciphertext em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext = unhexlify(ciphertext_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext)

    # Apresenta a chave secreta compartilhada (Shared Secret)
    print("\n===== Descriptografia Completa =====")
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber")
    print("2: Descriptografar um texto usando Kyber")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber
# 2: Descriptografar um texto usando Kyber
# Digite o número da opção desejada:  2
# === Descriptografar ===
# Digite a Private Key em hex:  ...
# Digite o Ciphertext em hex:  ...
# ===== Descriptografia Completa =====
# Shared Secret Decapsulado (hex): 4b4492315745b37175bb352278c2948691de06609d2544cb97d0dc09b7c64730

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    
    # Cria um nonce aleatório
    nonce = get_random_bytes(12)
    
    # Cria o cifrador AES usando a chave compartilhada
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Criptografa o texto e gera o tag para verificação de integridade
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    
    # Cria o cifrador AES com a chave compartilhada e o nonce
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Descriptografa o texto e verifica o tag
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Entrada do texto pelo usuário
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    # Realiza a encapsulação (criptografia) usando a chave pública para obter a chave compartilhada
    shared_secret, ciphertext_kem = kem_encaps512(pub_key)

    # Agora usamos a chave compartilhada para criptografar o texto com AES
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna as chaves e ciphertexts
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada para obter a chave compartilhada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)

    # Descriptografa o texto usando AES com a chave compartilhada
    plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)

    # Apresenta o texto descriptografado
    print("\n===== Descriptografia Completa =====")
    print(f"Texto descriptografado: {plaintext.decode()}")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  Teste
# ===== Criptografia Completa =====
# Texto original: Teste
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): d41a4f15b0f38e07fdb7846b0332150a65bd4d3aa43f5850b703c1a8369d427e
# Ciphertext KEM (hex): ...
# Nonce (hex): f145c6f703282867b7b85790
# Ciphertext AES (hex): 8b19beab07
# Tag (hex): 566b80688182a921c47ab83133d3d5cf

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    
    # Cria um nonce aleatório
    nonce = get_random_bytes(12)
    
    # Cria o cifrador AES usando a chave compartilhada
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Criptografa o texto e gera o tag para verificação de integridade
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    
    # Cria o cifrador AES com a chave compartilhada e o nonce
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Descriptografa o texto e verifica o tag
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Entrada do texto pelo usuário
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    # Realiza a encapsulação (criptografia) usando a chave pública para obter a chave compartilhada
    shared_secret, ciphertext_kem = kem_encaps512(pub_key)

    # Agora usamos a chave compartilhada para criptografar o texto com AES
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna as chaves e ciphertexts
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada para obter a chave compartilhada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)

    # Verificação de consistência da chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Descriptografa o texto usando AES com a chave compartilhada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# Digite o número da opção desejada:  2
# === Descriptografar ===
# Digite a Private Key em hex:  ...
# Digite o Ciphertext KEM em hex:  ...
# Digite o Nonce em hex:  f145c6f703282867b7b85790
# Digite o Ciphertext AES em hex:  8b19beab07
# Digite o Tag em hex:  566b80688182a921c47ab83133d3d5cf
# Shared Secret Decapsulado (hex): a0cb3bceb67aa9166a93a3ee0e7f1a0ca5f25472b02e4c2b1b9453eb9e323c5d
# Erro na verificação do MAC: MAC check failed
# Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    # Cria um nonce aleatório
    nonce = get_random_bytes(12)
    
    # Cria o cifrador AES usando a chave compartilhada
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Criptografa o texto e gera o tag para verificação de integridade
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    # Cria o cifrador AES com a chave compartilhada e o nonce
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Descriptografa o texto e verifica o tag
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Entrada do texto pelo usuário
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    # Realiza a encapsulação (criptografia) usando a chave pública para obter a chave compartilhada
    shared_secret, ciphertext_kem = kem_encaps512(pub_key)

    # Agora usamos a chave compartilhada para criptografar o texto com AES
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna as chaves e ciphertexts
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada para obter a chave compartilhada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)

    # Verificação de consistência da chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Descriptografa o texto usando AES com a chave compartilhada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  3
# === Testar Criptografia e Descriptografia ===
#
# === Teste Completo de Criptografia e Descriptografia ===
# Digite o texto que deseja criptografar:  Teste
# Chave AES usada para criptografar (hex): 764668c95e9729feb32d6ef7e6d29231
# ===== Criptografia Completa =====
# Texto original: Teste
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 764668c95e9729feb32d6ef7e6d29231df8dd21860f3ead21aa83278c86d6d57
# Ciphertext KEM (hex): ...
# Nonce (hex): a36744306ecf3eab9fc5ff67
# Ciphertext AES (hex): 5450dc1d00
# Tag (hex): dfb00228c7597201df976a2f3f528bff
#
# === Agora realizando a descriptografia ===
# Chave AES usada para descriptografar (hex): 764668c95e9729feb32d6ef7e6d29231
#
# ===== Teste Completo Concluído =====
# Texto descriptografado: Teste

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    # Cria um nonce aleatório
    nonce = get_random_bytes(12)
    
    # Cria o cifrador AES usando a chave compartilhada
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Criptografa o texto e gera o tag para verificação de integridade
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    # Cria o cifrador AES com a chave compartilhada e o nonce
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Descriptografa o texto e verifica o tag
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Entrada do texto pelo usuário
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    # Realiza a encapsulação (criptografia) usando a chave pública para obter a chave compartilhada
    shared_secret, ciphertext_kem = kem_encaps512(pub_key)

    # Agora usamos a chave compartilhada para criptografar o texto com AES
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna as chaves e ciphertexts
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada para obter a chave compartilhada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)

    # Verificação de consistência da chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Descriptografa o texto usando AES com a chave compartilhada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  Teste
# Chave AES usada para criptografar (hex): 08955cdcbf3c31ebcbf46b8a50ed2951
# ===== Criptografia Completa =====
# Texto original: Teste
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 08955cdcbf3c31ebcbf46b8a50ed2951c871df63483b6d9e32ced15e98f4f98f
# Ciphertext KEM (hex): ...
# Nonce (hex): 3ec0a126f60c9699bd67743b
# Ciphertext AES (hex): 3ea9a3442a
# Tag (hex): f3668184993c72fa0db58ebdeaa2f3e3

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    # Cria um nonce aleatório
    nonce = get_random_bytes(12)
    
    # Cria o cifrador AES usando a chave compartilhada
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Criptografa o texto e gera o tag para verificação de integridade
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    # Converte a chave compartilhada para o tipo bytes
    key = list_to_bytes(shared_secret[:16])
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    # Cria o cifrador AES com a chave compartilhada e o nonce
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    # Descriptografa o texto e verifica o tag
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    # Gera as chaves pública e privada usando Kyber-512
    priv_key, pub_key = kem_keygen512()

    # Entrada do texto pelo usuário
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    # Realiza a encapsulação (criptografia) usando a chave pública para obter a chave compartilhada
    shared_secret, ciphertext_kem = kem_encaps512(pub_key)

    # Agora usamos a chave compartilhada para criptografar o texto com AES
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)

    # Apresenta as informações necessárias para a descriptografia
    print("===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna as chaves e ciphertexts
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    # Solicitar ao usuário as informações necessárias
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais de volta para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Realiza a decapsulação (descriptografia) usando a chave privada para obter a chave compartilhada
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)

    # Verificação de consistência da chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Descriptografa o texto usando AES com a chave compartilhada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  2
# === Descriptografar ===
# Digite a Private Key em hex:  ...
# Digite o Ciphertext KEM em hex:  ...
# Digite o Nonce em hex:  3ec0a126f60c9699bd67743b
# Digite o Ciphertext AES em hex:  3ea9a3442a
# Digite o Tag em hex:  f3668184993c72fa0db58ebdeaa2f3e3
# Shared Secret Decapsulado (hex): a1a8203183360576d7c495a7863cd7503482403e723499f4d19d6f4e94f08957
# Chave AES usada para descriptografar (hex): a1a8203183360576d7c495a7863cd750
# Erro na verificação do MAC: MAC check failed
# Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag  # Retorna os dados gerados

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converte os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)  # Decapsula para obter chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  3
# === Testar Criptografia e Descriptografia ===
#
# === Teste Completo de Criptografia e Descriptografia ===
# Digite o texto que deseja criptografar:  Teste
# Chave AES usada para criptografar (hex): 0102e498bbcd07579078dbf4d0703f3f
#
# ===== Criptografia Completa =====
# Texto original: Teste
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 0102e498bbcd07579078dbf4d0703f3f8f9b8df0a2c94c991b4bc8da9c140dfa
# Ciphertext KEM (hex): ...
# Nonce (hex): 772cf5d4836a22d7f2f1be7e
# Ciphertext AES (hex): eb45d261ec
# Tag (hex): f304ed0901080aab4bcb656d9acb6a01
#
# === Agora realizando a descriptografia ===
# Chave AES usada para descriptografar (hex): 0102e498bbcd07579078dbf4d0703f3f
#
# ===== Teste Completo Concluído =====
# Texto descriptografado: Teste

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag  # Retorna os dados gerados

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converte os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)  # Decapsula para obter chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  Teste
# Chave AES usada para criptografar (hex): 1089ee60dcec50b164d59799e449fa04
#
# ===== Criptografia Completa =====
# Texto original: Teste
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 1089ee60dcec50b164d59799e449fa0420ac7ee365a38dbfbb8238a3639cafd1
# Ciphertext KEM (hex): ...
# Nonce (hex): 72b8f767b2c3a4f3e14167e0
# Ciphertext AES (hex): b4bcb1717e
# Tag (hex): baf32ab52b90511db60d93bde347176f

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag  # Retorna os dados gerados

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converte os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)  # Decapsula para obter chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  Teste
# Chave AES usada para criptografar (hex): 1089ee60dcec50b164d59799e449fa04
#
# ===== Criptografia Completa =====
# Texto original: Teste
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 1089ee60dcec50b164d59799e449fa0420ac7ee365a38dbfbb8238a3639cafd1
# Ciphertext KEM (hex): ...
# Nonce (hex): 72b8f767b2c3a4f3e14167e0
# Ciphertext AES (hex): b4bcb1717e
# Tag (hex): baf32ab52b90511db60d93bde347176f

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag  # Retorna os dados gerados

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converte os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)  # Decapsula para obter chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  2
# === Descriptografar ===
# Digite a Private Key em hex:  ...
# Digite o Ciphertext KEM em hex:  ...
# Digite o Nonce em hex:  72b8f767b2c3a4f3e14167e0
# Digite o Ciphertext AES em hex:  b4bcb1717e
# Digite o Tag em hex:  baf32ab52b90511db60d93bde347176f
# Shared Secret Decapsulado (hex): e4c120f2a3c727edadb51935c614ff5df023c485a712a9641963ec6510b1fede
# Chave AES usada para descriptografar (hex): e4c120f2a3c727edadb51935c614ff5d
# Erro na verificação do MAC: MAC check failed
# Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna os valores gerados para validação futura
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para comparar os valores inseridos com os gerados
def compare_values(label, original_value, input_value):
    if original_value != input_value:
        print(f"Erro: {label} fornecido é diferente do valor original.")
        return False
    return True

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt(orig_priv_key, orig_ciphertext_kem, orig_nonce, orig_ciphertext, orig_tag):
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Validar os valores inseridos com os valores originais
    if not compare_values("Private Key", orig_priv_key, priv_key): return
    if not compare_values("Ciphertext KEM", orig_ciphertext_kem, ciphertext_kem): return
    if not compare_values("Nonce", orig_nonce, nonce): return
    if not compare_values("Ciphertext AES", orig_ciphertext, ciphertext): return
    if not compare_values("Tag", orig_tag, tag): return

    # Se todos os valores forem iguais, procede para a decapsulação e descriptografia
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        # Use os valores gerados anteriormente na criptografia para comparação
        kyber_decrypt(priv_key, ciphertext_kem, nonce, ciphertext, tag)
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  IME
# Chave AES usada para criptografar (hex): e1422018da84335bd8a8ac1cef46d122
#
# ===== Criptografia Completa =====
# Texto original: IME
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): e1422018da84335bd8a8ac1cef46d1220ec726ffcc93d42e3f1b6ca9049ba4c4
# Ciphertext KEM (hex): ...
# Nonce (hex): ecc261c0bcf8fe3abaa97db1
# Ciphertext AES (hex): c65bf3
# Tag (hex): 58847b92d4d29524d8833a03a6bd176b

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna os valores gerados para validação futura
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para comparar os valores inseridos com os gerados
def compare_values(label, original_value, input_value):
    if original_value != input_value:
        print(f"Erro: {label} fornecido é diferente do valor original.")
        return False
    return True

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt(orig_priv_key, orig_ciphertext_kem, orig_nonce, orig_ciphertext, orig_tag):
    if not orig_priv_key or not orig_ciphertext_kem or not orig_nonce or not orig_ciphertext or not orig_tag:
        print("Erro: Criptografia não foi realizada. Por favor, criptografe um texto primeiro.")
        return

    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Validar os valores inseridos com os valores originais
    if not compare_values("Private Key", orig_priv_key, priv_key): return
    if not compare_values("Ciphertext KEM", orig_ciphertext_kem, ciphertext_kem): return
    if not compare_values("Nonce", orig_nonce, nonce): return
    if not compare_values("Ciphertext AES", orig_ciphertext, ciphertext): return
    if not compare_values("Tag", orig_tag, tag): return

    # Se todos os valores forem iguais, procede para a decapsulação e descriptografia
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    priv_key, ciphertext_kem, nonce, ciphertext, tag = None, None, None, None, None

    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        # Use os valores gerados anteriormente na criptografia para comparação
        kyber_decrypt(priv_key, ciphertext_kem, nonce, ciphertext, tag)
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  Teste IME
# Chave AES usada para criptografar (hex): 473cefad66b0ce0f600944378d378132
#
# ===== Criptografia Completa =====
# Texto original: Teste IME
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 473cefad66b0ce0f600944378d37813231769060b5aa705bc01760ffee4c04c4
# Ciphertext KEM (hex): ...
# Nonce (hex): 1f5fda234ab55643b7e22587
# Ciphertext AES (hex): c85598c02fc8225b64
# Tag (hex): a7d40d5c7ef05222a40e6e28fa58adb3

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    # Retorna os valores gerados para validação futura
    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para comparar os valores inseridos com os gerados
def compare_values(label, original_value, input_value):
    if original_value != input_value:
        print(f"Erro: {label} fornecido é diferente do valor original.")
        return False
    return True

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt(orig_priv_key, orig_ciphertext_kem, orig_nonce, orig_ciphertext, orig_tag):
    if not orig_priv_key or not orig_ciphertext_kem or not orig_nonce or not orig_ciphertext or not orig_tag:
        print("Erro: Criptografia não foi realizada. Por favor, criptografe um texto primeiro.")
        return

    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Validar os valores inseridos com os valores originais
    if not compare_values("Private Key", orig_priv_key, priv_key): return
    if not compare_values("Ciphertext KEM", orig_ciphertext_kem, ciphertext_kem): return
    if not compare_values("Nonce", orig_nonce, nonce): return
    if not compare_values("Ciphertext AES", orig_ciphertext, ciphertext): return
    if not compare_values("Tag", orig_tag, tag): return

    # Se todos os valores forem iguais, procede para a decapsulação e descriptografia
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    priv_key, ciphertext_kem, nonce, ciphertext, tag = None, None, None, None, None

    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        # Use os valores gerados anteriormente na criptografia para comparação
        kyber_decrypt(priv_key, ciphertext_kem, nonce, ciphertext, tag)
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  2
# === Descriptografar ===
# Erro: Criptografia não foi realizada. Por favor, criptografe um texto primeiro.

# %%
# Variáveis globais para armazenar os dados gerados pela criptografia
priv_key = None
ciphertext_kem = None
nonce = None
ciphertext = None
tag = None

def safe_hexlify(data):
    if isinstance(data, list):
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

def kyber_encrypt():
    global priv_key, ciphertext_kem, nonce, ciphertext, tag  # Usar variáveis globais
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

def compare_values(label, original_value, input_value):
    if original_value != input_value:
        print(f"Erro: {label} fornecido é diferente do valor original.")
        return False
    return True

def kyber_decrypt():
    global priv_key, ciphertext_kem, nonce, ciphertext, tag  # Usar variáveis globais
    
    if not priv_key or not ciphertext_kem or not nonce or not ciphertext or not tag:
        print("Erro: Criptografia não foi realizada. Por favor, criptografe um texto primeiro.")
        return

    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais fornecidos para bytes
    priv_key_input = unhexlify(priv_key_hex)
    ciphertext_kem_input = unhexlify(ciphertext_kem_hex)
    nonce_input = unhexlify(nonce_hex)
    ciphertext_input = unhexlify(ciphertext_hex)
    tag_input = unhexlify(tag_hex)

    # Validar os valores inseridos com os valores originais
    if not compare_values("Private Key", priv_key, priv_key_input): return
    if not compare_values("Ciphertext KEM", ciphertext_kem, ciphertext_kem_input): return
    if not compare_values("Nonce", nonce, nonce_input): return
    if not compare_values("Ciphertext AES", ciphertext, ciphertext_input): return
    if not compare_values("Tag", tag, tag_input): return

    # Se todos os valores forem iguais, procede para a decapsulação e descriptografia
    shared_secret_dec = kem_decaps512(priv_key_input, ciphertext_kem_input)
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce_input, ciphertext_input, tag_input)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    kyber_encrypt()
    print("\n=== Agora realizando a descriptografia ===")
    kyber_decrypt()

def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  1
# === Criptografar ===
# Digite o texto que deseja criptografar:  Teste iME
# Chave AES usada para criptografar (hex): 36516c01dcd7b77668c96feb9dfaf0f9
#
# ===== Criptografia Completa =====
# Texto original: Teste iME
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 36516c01dcd7b77668c96feb9dfaf0f9029858341fdfb827e4ce21b6fdd622ed
# Ciphertext KEM (hex): ...
# Nonce (hex): baea48b62b34a92c849947f6
# Ciphertext AES (hex): 3bc899c4134e959911
# Tag (hex): 9704c941ec470006683dbd35ae448b39

# %%
# Variáveis globais para armazenar os dados gerados pela criptografia
priv_key = None
ciphertext_kem = None
nonce = None
ciphertext = None
tag = None

def safe_hexlify(data):
    if isinstance(data, list):
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

def kyber_encrypt():
    global priv_key, ciphertext_kem, nonce, ciphertext, tag  # Usar variáveis globais
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

def compare_values(label, original_value, input_value):
    if original_value != input_value:
        print(f"Erro: {label} fornecido é diferente do valor original.")
        return False
    return True

def kyber_decrypt():
    global priv_key, ciphertext_kem, nonce, ciphertext, tag  # Usar variáveis globais
    
    if not priv_key or not ciphertext_kem or not nonce or not ciphertext or not tag:
        print("Erro: Criptografia não foi realizada. Por favor, criptografe um texto primeiro.")
        return

    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais fornecidos para bytes
    priv_key_input = unhexlify(priv_key_hex)
    ciphertext_kem_input = unhexlify(ciphertext_kem_hex)
    nonce_input = unhexlify(nonce_hex)
    ciphertext_input = unhexlify(ciphertext_hex)
    tag_input = unhexlify(tag_hex)

    # Validar os valores inseridos com os valores originais
    if not compare_values("Private Key", priv_key, priv_key_input): return
    if not compare_values("Ciphertext KEM", ciphertext_kem, ciphertext_kem_input): return
    if not compare_values("Nonce", nonce, nonce_input): return
    if not compare_values("Ciphertext AES", ciphertext, ciphertext_input): return
    if not compare_values("Tag", tag, tag_input): return

    # Se todos os valores forem iguais, procede para a decapsulação e descriptografia
    shared_secret_dec = kem_decaps512(priv_key_input, ciphertext_kem_input)
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce_input, ciphertext_input, tag_input)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    kyber_encrypt()
    print("\n=== Agora realizando a descriptografia ===")
    kyber_decrypt()

def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  2
# === Descriptografar ===
# Erro: Criptografia não foi realizada. Por favor, criptografe um texto primeiro.

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from ccakem import kem_keygen768, kem_encaps768, kem_decaps768
from ccakem import kem_keygen1024, kem_encaps1024, kem_decaps1024
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt(level):
    # Seleciona o nível de segurança baseado na escolha do usuário
    if level == 512:
        priv_key, pub_key = kem_keygen512()
        shared_secret, ciphertext_kem = kem_encaps512(pub_key)
    elif level == 768:
        priv_key, pub_key = kem_keygen768()
        shared_secret, ciphertext_kem = kem_encaps768(pub_key)
    elif level == 1024:
        priv_key, pub_key = kem_keygen1024()
        shared_secret, ciphertext_kem = kem_encaps1024(pub_key)
    else:
        raise ValueError("Nível de segurança inválido. Escolha 512, 768 ou 1024.")

    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para comparar os valores inseridos com os gerados
def compare_values(label, original_value, input_value):
    if original_value != input_value:
        print(f"Erro: {label} fornecido é diferente do valor original.")
        return False
    return True

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt(level, orig_priv_key, orig_ciphertext_kem, orig_nonce, orig_ciphertext, orig_tag):
    if not orig_priv_key or not orig_ciphertext_kem or not orig_nonce or not orig_ciphertext or not orig_tag:
        print("Erro: Criptografia não foi realizada. Por favor, criptografe um texto primeiro.")
        return

    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converter os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    # Validar os valores inseridos com os valores originais
    if not compare_values("Private Key", orig_priv_key, priv_key): return
    if not compare_values("Ciphertext KEM", orig_ciphertext_kem, ciphertext_kem): return
    if not compare_values("Nonce", orig_nonce, nonce): return
    if not compare_values("Ciphertext AES", orig_ciphertext, ciphertext): return
    if not compare_values("Tag", orig_tag, tag): return

    # Seleciona o nível de segurança baseado na escolha do usuário
    if level == 512:
        shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    elif level == 768:
        shared_secret_dec = kem_decaps768(priv_key, ciphertext_kem)
    elif level == 1024:
        shared_secret_dec = kem_decaps1024(priv_key, ciphertext_kem)
    else:
        raise ValueError("Nível de segurança inválido. Escolha 512, 768 ou 1024.")
    
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Seleciona o nível de segurança
    level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
    
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt(level)
    
    print("\n=== Agora realizando a descriptografia ===")
    kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag)

# Função principal que permite a seleção do usuário
def main():
    priv_key, ciphertext_kem, nonce, ciphertext, tag = None, None, None, None, None

    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt(level)
    elif choice == '2':
        print("\n=== Descriptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag)
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  3
# === Testar Criptografia e Descriptografia ===
#
# === Teste Completo de Criptografia e Descriptografia ===
# Selecione o nível de criptografia (512, 768, 1024):  512
# Digite o texto que deseja criptografar:  Teste IME
# Chave AES usada para criptografar (hex): 3ef0b727115d4ac7de758233f2dd80f9
#
# ===== Criptografia Completa =====
# Texto original: Teste IME
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 3ef0b727115d4ac7de758233f2dd80f94f10d76e9ab6b84e6ee2e04a5a27ee4b
# Ciphertext KEM (hex): ...
# Nonce (hex): 24ebaacace2ed944e22eacfa
# Ciphertext AES (hex): 7004779370be40b229
# Tag (hex): 3282420207905f3c5ec7c2c42db96e84
#
# === Agora realizando a descriptografia ===
# Digite a Private Key em hex:  ...
# Digite o Ciphertext KEM em hex:  ...
# Digite o Nonce em hex:  24ebaacace2ed944e22eacfa
# Digite o Ciphertext AES em hex:  7004779370be40b229
# Digite o Tag em hex:  3282420207905f3c5ec7c2c42db96e84
# Erro: Private Key fornecido é diferente do valor original.

# %%
import os
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt():
    priv_key, pub_key = kem_keygen512()  # Gera chaves pública e privada com Kyber-512
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')

    shared_secret, ciphertext_kem = kem_encaps512(pub_key)  # Encapsula para gerar chave compartilhada
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag  # Retorna os dados gerados

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt():
    priv_key_hex = input("Digite a Private Key em hex: ")
    ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
    nonce_hex = input("Digite o Nonce em hex: ")
    ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
    tag_hex = input("Digite o Tag em hex: ")

    # Converte os valores hexadecimais fornecidos para bytes
    priv_key = unhexlify(priv_key_hex)
    ciphertext_kem = unhexlify(ciphertext_kem_hex)
    nonce = unhexlify(nonce_hex)
    ciphertext = unhexlify(ciphertext_hex)
    tag = unhexlify(tag_hex)

    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)  # Decapsula para obter chave compartilhada
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para criptografar e descriptografar um texto em uma única etapa
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Realizar a criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = kyber_encrypt()
    
    print("\n=== Agora realizando a descriptografia ===")
    
    # Realizar a descriptografia imediatamente usando os mesmos dados gerados
    shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Teste Completo Concluído =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        kyber_encrypt()
    elif choice == '2':
        print("\n=== Descriptografar ===")
        kyber_decrypt()
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa
# Digite o número da opção desejada:  3
# === Testar Criptografia e Descriptografia ===
#
# === Teste Completo de Criptografia e Descriptografia ===
# Digite o texto que deseja criptografar:  Teste IME
# Chave AES usada para criptografar (hex): 24d45ecbc16d8c6e07e5b2d2c5325924
#
# ===== Criptografia Completa =====
# Texto original: Teste IME
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 24d45ecbc16d8c6e07e5b2d2c532592439cc28ca1af9eb461e84cdc7e840b2dd
# Ciphertext KEM (hex): ...
# Nonce (hex): 4ad7fa1c5536f69cf7c315d2
# Ciphertext AES (hex): cb6c7e819f4d3b328c
# Tag (hex): c642ddcd39986e43482efe5d7e36e854
#
# === Agora realizando a descriptografia ===
# Chave AES usada para descriptografar (hex): 24d45ecbc16d8c6e07e5b2d2c5325924
#
# ===== Teste Completo Concluído =====
# Texto descriptografado: Teste IME

# %%
import os
import time
import psutil
from memory_profiler import memory_usage
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from ccakem import kem_keygen768, kem_encaps768, kem_decaps768
from ccakem import kem_keygen1024, kem_encaps1024, kem_decaps1024
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt(level):
    # Seleciona a função correta com base no nível de criptografia
    if level == 512:
        priv_key, pub_key = kem_keygen512()
        shared_secret, ciphertext_kem = kem_encaps512(pub_key)
    elif level == 768:
        priv_key, pub_key = kem_keygen768()
        shared_secret, ciphertext_kem = kem_encaps768(pub_key)
    elif level == 1024:
        priv_key, pub_key = kem_keygen1024()
        shared_secret, ciphertext_kem = kem_encaps1024(pub_key)
    else:
        print("Nível de criptografia inválido. Selecione 512, 768 ou 1024.")
        return None, None, None, None, None

    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag):
    if level == 512:
        shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    elif level == 768:
        shared_secret_dec = kem_decaps768(priv_key, ciphertext_kem)
    elif level == 1024:
        shared_secret_dec = kem_decaps1024(priv_key, ciphertext_kem)
    else:
        print("Nível de criptografia inválido. Selecione 512, 768 ou 1024.")
        return
    
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para medir tempo, processamento e memória
def benchmark(function, *args):
    # Mede o tempo
    start_time = time.time()
    
    # Mede a utilização de CPU
    process = psutil.Process(os.getpid())
    cpu_before = process.cpu_percent(interval=None)
    
    # Mede a memória com o memory_profiler
    mem_before = memory_usage(-1, interval=0.1, timeout=1)
    
    result = function(*args)
    
    # Resultados de tempo e processamento
    end_time = time.time()
    cpu_after = process.cpu_percent(interval=None)
    mem_after = memory_usage(-1, interval=0.1, timeout=1)
    
    print(f"\nTempo total: {end_time - start_time:.4f} segundos")
    print(f"Utilização de CPU: {cpu_after - cpu_before:.4f}%")
    print(f"Memória usada: {max(mem_after) - max(mem_before):.4f} MiB")
    
    return result

# Função para criptografar e descriptografar um texto em uma única etapa com benchmark
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Solicita o nível de criptografia
    level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
    
    # Executa o benchmark para o processo de criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = benchmark(kyber_encrypt, level)
    
    if priv_key is None:
        return

    print("\n=== Agora realizando a descriptografia ===")
    
    # Executa o benchmark para o processo de descriptografia
    benchmark(kyber_decrypt, level, priv_key, ciphertext_kem, nonce, ciphertext, tag)

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa com benchmark")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        kyber_encrypt(level)
    elif choice == '2':
        print("\n=== Descriptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        # Descriptografar usando valores inseridos manualmente
        priv_key_hex = input("Digite a Private Key em hex: ")
        ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
        nonce_hex = input("Digite o Nonce em hex: ")
        ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
        tag_hex = input("Digite o Tag em hex: ")

        priv_key = unhexlify(priv_key_hex)
        ciphertext_kem = unhexlify(ciphertext_kem_hex)
        nonce = unhexlify(nonce_hex)
        ciphertext = unhexlify(ciphertext_hex)
        tag = unhexlify(tag_hex)

        kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag)
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia com Benchmark ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 4
#       2 import time
#       3 import psutil
# ----> 4 from memory_profiler import memory_usage
#       5 from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
#       6 from ccakem import kem_keygen768, kem_encaps768, kem_decaps768
#
# ModuleNotFoundError: No module named 'memory_profiler'

# %%
import os
import time
import psutil
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from ccakem import kem_keygen768, kem_encaps768, kem_decaps768
from ccakem import kem_keygen1024, kem_encaps1024, kem_decaps1024
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        # Aplicar uma máscara bit a bit para garantir que todos os valores fiquem entre 0 e 255
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt(level):
    # Seleciona a função correta com base no nível de criptografia
    if level == 512:
        priv_key, pub_key = kem_keygen512()
        shared_secret, ciphertext_kem = kem_encaps512(pub_key)
    elif level == 768:
        priv_key, pub_key = kem_keygen768()
        shared_secret, ciphertext_kem = kem_encaps768(pub_key)
    elif level == 1024:
        priv_key, pub_key = kem_keygen1024()
        shared_secret, ciphertext_kem = kem_encaps1024(pub_key)
    else:
        print("Nível de criptografia inválido. Selecione 512, 768 ou 1024.")
        return None, None, None, None, None

    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')
    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    print("\n===== Criptografia Completa =====")
    print(f"Texto original: {plaintext.decode()}")
    print(f"Private Key (hex): {safe_hexlify(priv_key)}")
    print(f"Public Key (hex): {safe_hexlify(pub_key)}")
    print(f"Shared Secret (hex): {safe_hexlify(shared_secret)}")
    print(f"Ciphertext KEM (hex): {safe_hexlify(ciphertext_kem)}")
    print(f"Nonce (hex): {safe_hexlify(nonce)}")
    print(f"Ciphertext AES (hex): {safe_hexlify(ciphertext)}")
    print(f"Tag (hex): {safe_hexlify(tag)}")

    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag):
    if level == 512:
        shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    elif level == 768:
        shared_secret_dec = kem_decaps768(priv_key, ciphertext_kem)
    elif level == 1024:
        shared_secret_dec = kem_decaps1024(priv_key, ciphertext_kem)
    else:
        print("Nível de criptografia inválido. Selecione 512, 768 ou 1024.")
        return
    
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para medir tempo, processamento e memória com psutil
def benchmark(function, *args):
    # Mede o tempo
    start_time = time.time()
    
    # Mede a utilização de CPU e memória
    process = psutil.Process(os.getpid())
    cpu_before = process.cpu_percent(interval=None)
    mem_before = process.memory_info().rss / 1024 / 1024  # Em MiB
    
    result = function(*args)
    
    # Resultados de tempo e processamento
    end_time = time.time()
    cpu_after = process.cpu_percent(interval=None)
    mem_after = process.memory_info().rss / 1024 / 1024  # Em MiB
    
    print(f"\nTempo total: {end_time - start_time:.4f} segundos")
    print(f"Utilização de CPU: {cpu_after - cpu_before:.4f}%")
    print(f"Memória usada: {mem_after - mem_before:.4f} MiB")
    
    return result

# Função para criptografar e descriptografar um texto em uma única etapa com benchmark
def test_encrypt_decrypt():
    print("\n=== Teste Completo de Criptografia e Descriptografia ===")
    
    # Solicita o nível de criptografia
    level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
    
    # Executa o benchmark para o processo de criptografia
    priv_key, ciphertext_kem, nonce, ciphertext, tag = benchmark(kyber_encrypt, level)
    
    if priv_key is None:
        return

    print("\n=== Agora realizando a descriptografia ===")
    
    # Executa o benchmark para o processo de descriptografia
    benchmark(kyber_decrypt, level, priv_key, ciphertext_kem, nonce, ciphertext, tag)

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa com benchmark")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        kyber_encrypt(level)
    elif choice == '2':
        print("\n=== Descriptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        # Descriptografar usando valores inseridos manualmente
        priv_key_hex = input("Digite a Private Key em hex: ")
        ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
        nonce_hex = input("Digite o Nonce em hex: ")
        ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
        tag_hex = input("Digite o Tag em hex: ")

        priv_key = unhexlify(priv_key_hex)
        ciphertext_kem = unhexlify(ciphertext_kem_hex)
        nonce = unhexlify(nonce_hex)
        ciphertext = unhexlify(ciphertext_hex)
        tag = unhexlify(tag_hex)

        kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag)
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia com Benchmark ===")
        test_encrypt_decrypt()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa com benchmark
# Digite o número da opção desejada:  3
# === Testar Criptografia e Descriptografia com Benchmark ===
#
# === Teste Completo de Criptografia e Descriptografia ===
# Selecione o nível de criptografia (512, 768, 1024):  1024
# Digite o texto que deseja criptografar:  Teste IME
# Chave AES usada para criptografar (hex): 20f079ae117bad01eef0e533bfe1a66e
#
# ===== Criptografia Completa =====
# Texto original: Teste IME
# Private Key (hex): ...
# Public Key (hex): ...
# Shared Secret (hex): 20f079ae117bad01eef0e533bfe1a66ed28bbd6ca089b1212f0e1fbd6a2d6670
# Ciphertext KEM (hex): ...
# Nonce (hex): 6b8b3c7ce3ce2b84d6575a72
# Ciphertext AES (hex): d281c3bf024d9ce85c
# Tag (hex): 410960559be785b19794d0f6c3b92e51
#
# Tempo total: 4.8320 segundos
# Utilização de CPU: 0.6000%
# Memória usada: 0.2422 MiB
#
# === Agora realizando a descriptografia ===
# Shared Secret Decapsulado (hex): 20f079ae117bad01eef0e533bfe1a66ed28bbd6ca089b1212f0e1fbd6a2d6670
# Chave AES usada para descriptografar (hex): 20f079ae117bad01eef0e533bfe1a66e
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste IME
#
# Tempo total: 0.0377 segundos
# Utilização de CPU: 50.4000%
# Memória usada: 0.0039 MiB
