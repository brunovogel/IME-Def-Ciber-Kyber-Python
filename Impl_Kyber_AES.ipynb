# %%
# !pip install pycryptodome psutil memory-profiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pycryptodome in c:\users\bruno\appdata\roaming\python\python312\site-packages (3.20.0)
# Requirement already satisfied: psutil in d:\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: memory-profiler in c:\users\bruno\appdata\roaming\python\python312\site-packages (0.61.0)

# %%
import os
import time
import psutil
from ccakem import kem_keygen512, kem_encaps512, kem_decaps512
from ccakem import kem_keygen768, kem_encaps768, kem_decaps768
from ccakem import kem_keygen1024, kem_encaps1024, kem_decaps1024
from binascii import unhexlify, hexlify
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from util import cast_to_byte

# Função para converter os dados para hexadecimal com máscara para garantir que os valores estejam entre 0 e 255
def safe_hexlify(data):
    if isinstance(data, list):
        data = [(x & 0xFF) for x in data]
    return hexlify(bytearray(data)).decode()

# Função para converter uma lista de inteiros em bytes
def list_to_bytes(data):
    return bytes([x & 0xFF for x in data])

# Função para salvar resultados do benchmark em um arquivo .txt
def save_benchmark_results_to_file(filename, level, repetitions, results):
    with open(filename, 'a') as f:
        f.write("\n===== Resultados do Benchmark =====\n")
        f.write(f"Tipo de Criptografia: Kyber-{level}\n")
        f.write(f"Quantidade de execuções: {repetitions}\n")
        for key, value in results.items():
            f.write(f'{key}: {value}\n')
        f.write("=====================================\n")

# Função para salvar resultados da criptografia em um arquivo .txt
def save_crypto_results_to_file(filename, level, results):
    with open(filename, 'a') as f:
        f.write("\n===== Resultados da Criptografia =====\n")
        f.write(f"Tipo de Criptografia: Kyber-{level}\n")
        for key, value in results.items():
            f.write(f'{key}: "{value}"\n')
        f.write("=====================================\n")

# Função para criptografar o texto usando AES
def aes_encrypt(shared_secret, plaintext):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para criptografar (hex): {hexlify(key).decode()}")
    
    nonce = get_random_bytes(12)  # Gerando nonce de 12 bytes
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    
    ciphertext, tag = cipher.encrypt_and_digest(plaintext)
    return nonce, ciphertext, tag

# Função para descriptografar o texto usando AES
def aes_decrypt(shared_secret, nonce, ciphertext, tag):
    key = list_to_bytes(shared_secret[:16])  # Truncando o Shared Secret para 16 bytes
    print(f"Chave AES usada para descriptografar (hex): {hexlify(key).decode()}")
    
    cipher = AES.new(key, AES.MODE_GCM, nonce=nonce)
    plaintext = cipher.decrypt_and_verify(ciphertext, tag)
    return plaintext

# Função para criptografar um texto com Kyber e AES
def kyber_encrypt(level, plaintext):
    if level == 512:
        priv_key, pub_key = kem_keygen512()
        shared_secret, ciphertext_kem = kem_encaps512(pub_key)
    elif level == 768:
        priv_key, pub_key = kem_keygen768()
        shared_secret, ciphertext_kem = kem_encaps768(pub_key)
    elif level == 1024:
        priv_key, pub_key = kem_keygen1024()
        shared_secret, ciphertext_kem = kem_encaps1024(pub_key)
    else:
        print("Nível de criptografia inválido. Selecione 512, 768 ou 1024.")
        return None, None, None, None, None

    nonce, ciphertext, tag = aes_encrypt(shared_secret, plaintext)  # Criptografa o texto com AES

    # Salvar resultados da criptografia
    results = {
        "Private Key (hex)": safe_hexlify(priv_key),
        "Public Key (hex)": safe_hexlify(pub_key),
        "Shared Secret (hex)": safe_hexlify(shared_secret),
        "Ciphertext KEM (hex)": safe_hexlify(ciphertext_kem),
        "Nonce (hex)": safe_hexlify(nonce),
        "Ciphertext AES (hex)": safe_hexlify(ciphertext),
        "Tag (hex)": safe_hexlify(tag)
    }
    save_crypto_results_to_file('kyber_cryptography_results.txt', level, results)

    print("\n===== Criptografia Completa =====")
    for key, value in results.items():
        print(f'{key}: "{value}"')

    return priv_key, ciphertext_kem, nonce, ciphertext, tag

# Função para descriptografar o texto com Kyber e AES
def kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag):
    if level == 512:
        shared_secret_dec = kem_decaps512(priv_key, ciphertext_kem)
    elif level == 768:
        shared_secret_dec = kem_decaps768(priv_key, ciphertext_kem)
    elif level == 1024:
        shared_secret_dec = kem_decaps1024(priv_key, ciphertext_kem)
    else:
        print("Nível de criptografia inválido. Selecione 512, 768 ou 1024.")
        return
    
    print(f"Shared Secret Decapsulado (hex): {safe_hexlify(shared_secret_dec)}")

    # Tenta descriptografar o texto usando AES com a chave compartilhada decapsulada
    try:
        plaintext = aes_decrypt(shared_secret_dec, nonce, ciphertext, tag)
        print("\n===== Descriptografia Completa =====")
        print(f"Texto descriptografado: {plaintext.decode()}")
    except ValueError as e:
        print(f"Erro na verificação do MAC: {e}")
        print("Verifique se todas as informações inseridas (chaves, nonce, ciphertext e tag) estão corretas.")

# Função para medir tempo, processamento e memória com psutil
def benchmark(function, *args):
    start_time = time.time()  # Mede o tempo
    process = psutil.Process(os.getpid())  # Processo atual
    cpu_before = process.cpu_percent(interval=None) / psutil.cpu_count(logical=False)  # CPU antes por núcleo
    mem_before = process.memory_info().rss / 1024 / 1024  # Memória antes

    result = function(*args)  # Executa a função

    end_time = time.time()  # Tempo final
    cpu_after = process.cpu_percent(interval=None) / psutil.cpu_count(logical=False)  # CPU depois por núcleo
    mem_after = process.memory_info().rss / 1024 / 1024  # Memória depois

    # Calcula métricas de desempenho
    time_elapsed = end_time - start_time
    cpu_used = cpu_after - cpu_before
    mem_used = mem_after - mem_before

    # Retorna métricas para análise
    return time_elapsed, cpu_used, mem_used, result

# Função para criptografar e descriptografar repetidamente
def test_encrypt_decrypt_stress():
    print("\n=== Teste de Criptografia e Descriptografia Repetida ===")

    # Solicita o nível de criptografia, o texto e o número de repetições
    level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
    plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')
    repetitions = int(input("Quantas vezes deseja repetir o teste?: "))

    # Variáveis para armazenar métricas
    total_time = 0
    total_cpu = 0
    total_mem = 0
    max_cpu = 0
    max_mem = 0

    for i in range(repetitions):
        print(f"\n--- Iteração {i+1} de {repetitions} ---")
        
        # Criptografia
        time_elapsed, cpu_used, mem_used, (priv_key, ciphertext_kem, nonce, ciphertext, tag) = benchmark(kyber_encrypt, level, plaintext)
        
        if priv_key is None:
            return

        # Descriptografia
        time_elapsed_dec, cpu_used_dec, mem_used_dec, _ = benchmark(kyber_decrypt, level, priv_key, ciphertext_kem, nonce, ciphertext, tag)

        # Atualiza as métricas
        total_time += (time_elapsed + time_elapsed_dec)
        total_cpu += (cpu_used + cpu_used_dec)
        total_mem += (mem_used + mem_used_dec)

        # Verifica máximo de CPU e Memória
        max_cpu = max(max_cpu, cpu_used, cpu_used_dec)
        max_mem = max(max_mem, mem_used, mem_used_dec)

    # Cálculo de métricas médias
    avg_cpu = total_cpu / (2 * repetitions)
    avg_mem = total_mem / (2 * repetitions)

    # Salvar os resultados do benchmark
    benchmark_results = {
        "Tempo total": f"{total_time:.4f} segundos",
        "Consumo máximo de CPU": f"{max_cpu:.4f}%",
        "Consumo máximo de Memória": f"{max_mem:.4f} MiB",
        "Média de consumo de CPU": f"{avg_cpu:.4f}%",
        "Média de consumo de Memória": f"{avg_mem:.4f} MiB"
    }
    save_benchmark_results_to_file('kyber_benchmark_results.txt', level, repetitions, benchmark_results)

    # Exibe análise final
    print("\n===== Análise Final =====")
    print(f"Tempo total: {total_time:.4f} segundos")
    print(f"Consumo máximo de CPU: {max_cpu:.4f}%")
    print(f"Consumo máximo de Memória: {max_mem:.4f} MiB")
    print(f"Média de consumo de CPU: {avg_cpu:.4f}%")
    print(f"Média de consumo de Memória: {avg_mem:.4f} MiB")

# Função principal que permite a seleção do usuário
def main():
    print("Selecione uma opção:")
    print("1: Criptografar um texto usando Kyber e AES")
    print("2: Descriptografar um texto usando Kyber e AES")
    print("3: Testar Criptografia e Descriptografia em uma única etapa com benchmark")
    #print("4: Testar Criptografia e Descriptografia repetidamente para estresse de processamento")
    
    choice = input("Digite o número da opção desejada: ")
    
    if choice == '1':
        print("\n=== Criptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        plaintext = input("Digite o texto que deseja criptografar: ").encode('utf-8')
        kyber_encrypt(level, plaintext)
    elif choice == '2':
        print("\n=== Descriptografar ===")
        level = int(input("Selecione o nível de criptografia (512, 768, 1024): "))
        priv_key_hex = input("Digite a Private Key em hex: ")
        ciphertext_kem_hex = input("Digite o Ciphertext KEM em hex: ")
        nonce_hex = input("Digite o Nonce em hex: ")
        ciphertext_hex = input("Digite o Ciphertext AES em hex: ")
        tag_hex = input("Digite o Tag em hex: ")

        priv_key = unhexlify(priv_key_hex)
        ciphertext_kem = unhexlify(ciphertext_kem_hex)
        nonce = unhexlify(nonce_hex)
        ciphertext = unhexlify(ciphertext_hex)
        tag = unhexlify(tag_hex)

        kyber_decrypt(level, priv_key, ciphertext_kem, nonce, ciphertext, tag)
    elif choice == '3':
        print("\n=== Testar Criptografia e Descriptografia com Benchmark ===")
        test_encrypt_decrypt_stress()
    elif choice == '4':
        print("\n=== Testar Criptografia e Descriptografia repetidamente ===")
        test_encrypt_decrypt_stress()
    else:
        print("Escolha inválida.")

if __name__ == "__main__":
    main()
# Out:
# Selecione uma opção:
# 1: Criptografar um texto usando Kyber e AES
# 2: Descriptografar um texto usando Kyber e AES
# 3: Testar Criptografia e Descriptografia em uma única etapa com benchmark
# Digite o número da opção desejada:  3
# === Testar Criptografia e Descriptografia com Benchmark ===
#
# === Teste de Criptografia e Descriptografia Repetida ===
# Selecione o nível de criptografia (512, 768, 1024):  512
# Digite o texto que deseja criptografar:  Teste de implementação Kyber IME
# Quantas vezes deseja repetir o teste?:  100
# --- Iteração 1 de 100 ---
# Chave AES usada para criptografar (hex): 73d76014ccd1daad8499216ebbd59408
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "73d76014ccd1daad8499216ebbd59408882fb5a7c53821d7915da73d6ba98802"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "023e2bb8ba788899bf192712"
# Ciphertext AES (hex): "a85b564aaff4dfed44036baabe71e9efd2001a2be8c8bd35454189ac1c934fd0a47f"
# Tag (hex): "3dcf7d21631c976b20b6b88352b04f04"
# Shared Secret Decapsulado (hex): 73d76014ccd1daad8499216ebbd59408882fb5a7c53821d7915da73d6ba98802
# Chave AES usada para descriptografar (hex): 73d76014ccd1daad8499216ebbd59408
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 2 de 100 ---
# Chave AES usada para criptografar (hex): 26bbc92c6c199261fc5f07a0c6ffb08e
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "26bbc92c6c199261fc5f07a0c6ffb08e928cc9ce8a341ecf126e981a27f134fe"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "77102d306a5aa3c985983734"
# Ciphertext AES (hex): "e2eed8b67d2cfbbd10fc1a16dd7850c858b3b8a95a8e3cdc4cac8e07b794d7f93da1"
# Tag (hex): "85689a587cc898a14b7d19953783f05e"
# Shared Secret Decapsulado (hex): 26bbc92c6c199261fc5f07a0c6ffb08e928cc9ce8a341ecf126e981a27f134fe
# Chave AES usada para descriptografar (hex): 26bbc92c6c199261fc5f07a0c6ffb08e
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 3 de 100 ---
# Chave AES usada para criptografar (hex): b674d4d44b07ed35834ac62381d1f6a8
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "b674d4d44b07ed35834ac62381d1f6a8a74e233b46722688776402926e897ec8"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "8a0e06b694107702efb05c49"
# Ciphertext AES (hex): "1a3e8677a9c8551e6c747c4ab7a440f37e283276ec9198b4a90e532a2b7ac50760f7"
# Tag (hex): "ce7e835c406928891c6d2ebadef940a4"
# Shared Secret Decapsulado (hex): b674d4d44b07ed35834ac62381d1f6a8a74e233b46722688776402926e897ec8
# Chave AES usada para descriptografar (hex): b674d4d44b07ed35834ac62381d1f6a8
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 4 de 100 ---
# Chave AES usada para criptografar (hex): 0c338301a560f74082bf8fa8d987fe2b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "0c338301a560f74082bf8fa8d987fe2bfdd42a83642ab2c269485ceb5268c2e1"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "51e27beb5c2959fdceac8bff"
# Ciphertext AES (hex): "d6a988965961eb3298c89c0208ca2ae8e550f4fda740eacc2263d29ca032e7de7780"
# Tag (hex): "38a847b19064f3d8f5d393b2729511ce"
# Shared Secret Decapsulado (hex): 0c338301a560f74082bf8fa8d987fe2bfdd42a83642ab2c269485ceb5268c2e1
# Chave AES usada para descriptografar (hex): 0c338301a560f74082bf8fa8d987fe2b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 5 de 100 ---
# Chave AES usada para criptografar (hex): 1ebcceeb943c78c3b43f3b5a3ec4bc2f
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "1ebcceeb943c78c3b43f3b5a3ec4bc2f387438b21a18a8f8d7559fa8c716096d"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "116768be4ef01c625166e705"
# Ciphertext AES (hex): "bd753f8623f9e5b84683d5fec3e31309439ce7a0d1f5bc198bb60cd0ea6ccfea94e8"
# Tag (hex): "8ee809db7e74443bfcecb2c5c8d4edd0"
# Shared Secret Decapsulado (hex): 1ebcceeb943c78c3b43f3b5a3ec4bc2f387438b21a18a8f8d7559fa8c716096d
# Chave AES usada para descriptografar (hex): 1ebcceeb943c78c3b43f3b5a3ec4bc2f
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 6 de 100 ---
# Chave AES usada para criptografar (hex): 4dcb5a7428d874db95301997521a28f7
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "4dcb5a7428d874db95301997521a28f7c7ebf9644c8e1ad66f8ca726db227d32"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "707f98b367ae8518a1fbfc94"
# Ciphertext AES (hex): "96f30357f9e26191d5d9548fadb12a12bd5904bdc880f7fd352f4ce5d2dfda0ea5e2"
# Tag (hex): "54042caa63905501434351d2d2a095fd"
# Shared Secret Decapsulado (hex): 4dcb5a7428d874db95301997521a28f7c7ebf9644c8e1ad66f8ca726db227d32
# Chave AES usada para descriptografar (hex): 4dcb5a7428d874db95301997521a28f7
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 7 de 100 ---
# Chave AES usada para criptografar (hex): 8d2f47dcd35bfe54ade495e9ab6750a3
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "8d2f47dcd35bfe54ade495e9ab6750a3d12eb41dc1f4aa11e8811c4731bba769"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "33057be83098b62578f263ee"
# Ciphertext AES (hex): "85a2175dfc1efb539bdaa0bf2129e8ad92a9cc3671c4d945f0afdb339a2ecc98ae9d"
# Tag (hex): "0ad2b1d88d09475680e48fcacbad3f76"
# Shared Secret Decapsulado (hex): 8d2f47dcd35bfe54ade495e9ab6750a3d12eb41dc1f4aa11e8811c4731bba769
# Chave AES usada para descriptografar (hex): 8d2f47dcd35bfe54ade495e9ab6750a3
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 8 de 100 ---
# Chave AES usada para criptografar (hex): 0deca41314330adeec4f445d3669d1d2
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "0deca41314330adeec4f445d3669d1d2e5bcf8e5916a50a61e03de85e9d2f96c"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "845ae62c0ceadcac9d0504c4"
# Ciphertext AES (hex): "5b30addddca019b1d5acbd01f3bfd3c8cc26e6c2f15dbebb549b6734f93e6ab63b61"
# Tag (hex): "b7f97adc9fcbb6981086b96bf4abc8f7"
# Shared Secret Decapsulado (hex): 0deca41314330adeec4f445d3669d1d2e5bcf8e5916a50a61e03de85e9d2f96c
# Chave AES usada para descriptografar (hex): 0deca41314330adeec4f445d3669d1d2
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 9 de 100 ---
# Chave AES usada para criptografar (hex): 82801cf39f05b968693788bf5342d593
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "82801cf39f05b968693788bf5342d593897ecf53967f1691b7d9b760c5f81ced"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "3552defc163b30631ec013d4"
# Ciphertext AES (hex): "37d51d0a3ddb6671ec6cc6e2a39abbf40bef7b2548853dc1192ef3a0af6f2865617d"
# Tag (hex): "5faa6c328ab9539e77597c16d43ce812"
# Shared Secret Decapsulado (hex): 82801cf39f05b968693788bf5342d593897ecf53967f1691b7d9b760c5f81ced
# Chave AES usada para descriptografar (hex): 82801cf39f05b968693788bf5342d593
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 10 de 100 ---
# Chave AES usada para criptografar (hex): f96b554b54112da2a8b5291a05793288
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "f96b554b54112da2a8b5291a057932882febc3ff04c26fef4584f782809d8595"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "5f5a2448000541e5e1cddcea"
# Ciphertext AES (hex): "e37b79c547ef7251c8f37d07d2a33e28f8e7496bc96a8d35c029144dbf6d172e2a40"
# Tag (hex): "435446d212d798b3f15eb0cd496a0221"
# Shared Secret Decapsulado (hex): f96b554b54112da2a8b5291a057932882febc3ff04c26fef4584f782809d8595
# Chave AES usada para descriptografar (hex): f96b554b54112da2a8b5291a05793288
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 11 de 100 ---
# Chave AES usada para criptografar (hex): f258fbf1f02e603bdc1f71acc2048bac
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "f258fbf1f02e603bdc1f71acc2048bac12e569159b225b91255e2ab39b3e2557"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "c82b4752d34f2aac482601e5"
# Ciphertext AES (hex): "7f75977c9062efc60d5fde54e2f16319a9ff63e0ae8ec86cd7ba1083ebc13dece5fa"
# Tag (hex): "4247a745ee2a0f65636aacf8d72191ab"
# Shared Secret Decapsulado (hex): f258fbf1f02e603bdc1f71acc2048bac12e569159b225b91255e2ab39b3e2557
# Chave AES usada para descriptografar (hex): f258fbf1f02e603bdc1f71acc2048bac
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 12 de 100 ---
# Chave AES usada para criptografar (hex): 7d4af6854779acb1915b29aa87f95b2d
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "7d4af6854779acb1915b29aa87f95b2d0753d8f3e65f65a3dbb357680efb9c94"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "a4a2eba28a9be428d519b743"
# Ciphertext AES (hex): "6eee7f832387c941b5ffb616344e639919780ee1b9241f9b9e10c8a811f5a5d6d89f"
# Tag (hex): "6976e710d2e56b9be79e78e5b0b5a709"
# Shared Secret Decapsulado (hex): 7d4af6854779acb1915b29aa87f95b2d0753d8f3e65f65a3dbb357680efb9c94
# Chave AES usada para descriptografar (hex): 7d4af6854779acb1915b29aa87f95b2d
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 13 de 100 ---
# Chave AES usada para criptografar (hex): e8dbc5a4c208ff66bf579989a7592aa1
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "e8dbc5a4c208ff66bf579989a7592aa1aabf0804cbe79ccf59c1e8321e87195c"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "47c79df5d940d52ddba89f35"
# Ciphertext AES (hex): "5be8b2fddfce9fde4aba6dc71eefaceb39c7e3b7fa89a32e3f2d498efc8dbdee8eca"
# Tag (hex): "cd103c06cb0c6ddb9f9dd96ed287af6b"
# Shared Secret Decapsulado (hex): e8dbc5a4c208ff66bf579989a7592aa1aabf0804cbe79ccf59c1e8321e87195c
# Chave AES usada para descriptografar (hex): e8dbc5a4c208ff66bf579989a7592aa1
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 14 de 100 ---
# Chave AES usada para criptografar (hex): d5bcc97bfe640a5adf9ee79fa85d1412
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "d5bcc97bfe640a5adf9ee79fa85d14122d628f01e5146c6e416c687e949a44e7"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "77c3b1820edbe7ba4d676f3b"
# Ciphertext AES (hex): "ddf33bfbf20688a45da4a7f59df525e3982eb837f7aeb19cbfcc385b33c3b6a3bdac"
# Tag (hex): "7b1c97c96ac2f95015129c4ef9acc30f"
# Shared Secret Decapsulado (hex): d5bcc97bfe640a5adf9ee79fa85d14122d628f01e5146c6e416c687e949a44e7
# Chave AES usada para descriptografar (hex): d5bcc97bfe640a5adf9ee79fa85d1412
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 15 de 100 ---
# Chave AES usada para criptografar (hex): 63289eff04e3674ad7cdefdd76d5cb74
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "63289eff04e3674ad7cdefdd76d5cb74bdaa46164dca90f88dd4515c3fc53b82"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "3186735c6b05aceae8c5b4a1"
# Ciphertext AES (hex): "4a427f07821146c6e94dd68e95a80f3d4f878658ebda41473fa26889454d24b66762"
# Tag (hex): "9d309c06bb6d6d865acd7d7411c638ea"
# Shared Secret Decapsulado (hex): 63289eff04e3674ad7cdefdd76d5cb74bdaa46164dca90f88dd4515c3fc53b82
# Chave AES usada para descriptografar (hex): 63289eff04e3674ad7cdefdd76d5cb74
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 16 de 100 ---
# Chave AES usada para criptografar (hex): e9ec6f1f1627557935df40303e0bec1d
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "e9ec6f1f1627557935df40303e0bec1d67940a9a46344b566e5047720e16d536"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "74a76d2241855a6b1a617e21"
# Ciphertext AES (hex): "4391cb27cf77e2b84361845cb7dcadccd28cc2df197c0a800d6d235c019212d04908"
# Tag (hex): "8ea144bbe161b4dc98577049204d7779"
# Shared Secret Decapsulado (hex): e9ec6f1f1627557935df40303e0bec1d67940a9a46344b566e5047720e16d536
# Chave AES usada para descriptografar (hex): e9ec6f1f1627557935df40303e0bec1d
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 17 de 100 ---
# Chave AES usada para criptografar (hex): e8240771b7c18080d71d937b1ee0dfa9
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "e8240771b7c18080d71d937b1ee0dfa90371e74e747ee947fa8eb23d1e0dfe02"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "8f67e28767a450fde380aad8"
# Ciphertext AES (hex): "460a4370a57dad2cd17eedcf9150af4cd6d85d3f5b7555722e933d9dbaa34824c58e"
# Tag (hex): "60b80fa84d09bd30c143096476d8f4eb"
# Shared Secret Decapsulado (hex): e8240771b7c18080d71d937b1ee0dfa90371e74e747ee947fa8eb23d1e0dfe02
# Chave AES usada para descriptografar (hex): e8240771b7c18080d71d937b1ee0dfa9
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 18 de 100 ---
# Chave AES usada para criptografar (hex): dc1ccdaca7a569b5a4f988755aab6ac8
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "dc1ccdaca7a569b5a4f988755aab6ac8e71536d07bd6473c018d5d58dac77e99"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "704c0e75c90a3706839643f7"
# Ciphertext AES (hex): "7d6df087f3c2b629505b635dbd90d4582e91c9d6b2f4f27b52f8ba5e831072e35a77"
# Tag (hex): "2dec4cc91630aec7296c31cfbcf861bc"
# Shared Secret Decapsulado (hex): dc1ccdaca7a569b5a4f988755aab6ac8e71536d07bd6473c018d5d58dac77e99
# Chave AES usada para descriptografar (hex): dc1ccdaca7a569b5a4f988755aab6ac8
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 19 de 100 ---
# Chave AES usada para criptografar (hex): a78981ebae34f552e53e2b7e1a855c10
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "a78981ebae34f552e53e2b7e1a855c10eadbf29a6d2bdc0d1502c8b3420524b8"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "24555955763488e1f619fa9e"
# Ciphertext AES (hex): "15acac41e736b001fb6ce43b873b14c8f0ba0598f30c2bf6a6ecda2d72539c1be161"
# Tag (hex): "c15b10ec76998852a7a81b423594e8eb"
# Shared Secret Decapsulado (hex): a78981ebae34f552e53e2b7e1a855c10eadbf29a6d2bdc0d1502c8b3420524b8
# Chave AES usada para descriptografar (hex): a78981ebae34f552e53e2b7e1a855c10
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 20 de 100 ---
# Chave AES usada para criptografar (hex): a1f4260a09cbdc79fd5923571c0b0e16
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "a1f4260a09cbdc79fd5923571c0b0e160ac4ab127af4711b7c93c9d04263db8e"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "c4b75dd85c89225d60688857"
# Ciphertext AES (hex): "3d70647706135d4bfa1d0180119e57e3cf827e4d96d3d7917a54ff652448feb88f4b"
# Tag (hex): "f624e3dc041cd57a920690ee1cda0f49"
# Shared Secret Decapsulado (hex): a1f4260a09cbdc79fd5923571c0b0e160ac4ab127af4711b7c93c9d04263db8e
# Chave AES usada para descriptografar (hex): a1f4260a09cbdc79fd5923571c0b0e16
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 21 de 100 ---
# Chave AES usada para criptografar (hex): 4f14e8aaae18a468e323f6f6fdb27bd9
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "4f14e8aaae18a468e323f6f6fdb27bd9f3ebeb98af2390b6d6dad76cf31c3e5e"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "a15202902d83d7212a6cc03b"
# Ciphertext AES (hex): "f4ff0bbc36ed5ec2f3736023051214505c0ffec37a71ef0ec87078442b70d090157f"
# Tag (hex): "a138640337a9c6e81d5f7c5ad1048ac7"
# Shared Secret Decapsulado (hex): 4f14e8aaae18a468e323f6f6fdb27bd9f3ebeb98af2390b6d6dad76cf31c3e5e
# Chave AES usada para descriptografar (hex): 4f14e8aaae18a468e323f6f6fdb27bd9
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 22 de 100 ---
# Chave AES usada para criptografar (hex): 4edb9dddee03f473edc88f07042c9ad1
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "4edb9dddee03f473edc88f07042c9ad1e4cbe4912fa26534bc9f482595cb4f42"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "f35f4b2eaf0f7a71973b57a6"
# Ciphertext AES (hex): "d2215de104ff28a4d817f37ae5a1b25b4763007d852203296447c1ecc89aaa5aa183"
# Tag (hex): "6f05d377776f34c893d763c8156c5d89"
# Shared Secret Decapsulado (hex): 4edb9dddee03f473edc88f07042c9ad1e4cbe4912fa26534bc9f482595cb4f42
# Chave AES usada para descriptografar (hex): 4edb9dddee03f473edc88f07042c9ad1
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 23 de 100 ---
# Chave AES usada para criptografar (hex): abd031cd6fadfbe006c91b159c4ea0ee
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "abd031cd6fadfbe006c91b159c4ea0ee5ed4b168cb819372a70df892638df977"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "bbf00e61bff34a88d112e07e"
# Ciphertext AES (hex): "85191a4c0c64d06b86215dbfc6048f70155f9a3a1bd8ac1c4c3bbae4108d924ad6fb"
# Tag (hex): "6a33c880d3eb6a90ce7c26860b126e63"
# Shared Secret Decapsulado (hex): abd031cd6fadfbe006c91b159c4ea0ee5ed4b168cb819372a70df892638df977
# Chave AES usada para descriptografar (hex): abd031cd6fadfbe006c91b159c4ea0ee
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 24 de 100 ---
# Chave AES usada para criptografar (hex): 776dbba6cead2fc1cc9ad11ed587fb81
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "776dbba6cead2fc1cc9ad11ed587fb813139fee83dada25588b5005176ecf2bc"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "94b8dc3d1f1a7c57b5235d0c"
# Ciphertext AES (hex): "bcc9925f9431fa3fffa81cc4fbb7a958946781a85aa14fd2a67f9ecdd7dbaeb8c8ea"
# Tag (hex): "dd8ca43cd6d2f4480ba134143b773fb1"
# Shared Secret Decapsulado (hex): 776dbba6cead2fc1cc9ad11ed587fb813139fee83dada25588b5005176ecf2bc
# Chave AES usada para descriptografar (hex): 776dbba6cead2fc1cc9ad11ed587fb81
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 25 de 100 ---
# Chave AES usada para criptografar (hex): 1f9e69f6c39701b647951c028400009b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "1f9e69f6c39701b647951c028400009bcf37d9d16d2bab303948565f9fc35725"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "877092e45fc7271b8574f44f"
# Ciphertext AES (hex): "b133ac80e9c25bb7dacd4464566664536ab03ee8a341bbb4920dfaff00efe4388ec1"
# Tag (hex): "dd5e64373cecb33ad67f6604cb26837b"
# Shared Secret Decapsulado (hex): 1f9e69f6c39701b647951c028400009bcf37d9d16d2bab303948565f9fc35725
# Chave AES usada para descriptografar (hex): 1f9e69f6c39701b647951c028400009b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 26 de 100 ---
# Chave AES usada para criptografar (hex): c432106ba05496f3bb3af6a55b8b132d
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "c432106ba05496f3bb3af6a55b8b132d3b8b37743ea2abcd1b7af49e3702cca2"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "dc7d18d516ebcc127dfd9cf9"
# Ciphertext AES (hex): "200f530a45d2b508045924945437f196365fc1d76fec4dae90f3ed58c4557bff862b"
# Tag (hex): "93524370becbf29e33170ae1f3ec7705"
# Shared Secret Decapsulado (hex): c432106ba05496f3bb3af6a55b8b132d3b8b37743ea2abcd1b7af49e3702cca2
# Chave AES usada para descriptografar (hex): c432106ba05496f3bb3af6a55b8b132d
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 27 de 100 ---
# Chave AES usada para criptografar (hex): 52c4231806631a9dba365a8917629caa
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "52c4231806631a9dba365a8917629caa677ca8ce8cab81bcfb41e674411ff510"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "099c8b9c6d21fc346ce360d1"
# Ciphertext AES (hex): "ab5676dea0da2e90856958baa09e7413358d01459aec7f6896f9ba6bd28dda1d161d"
# Tag (hex): "652bcf1cd73cc295ecac06fd940b45f8"
# Shared Secret Decapsulado (hex): 52c4231806631a9dba365a8917629caa677ca8ce8cab81bcfb41e674411ff510
# Chave AES usada para descriptografar (hex): 52c4231806631a9dba365a8917629caa
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 28 de 100 ---
# Chave AES usada para criptografar (hex): cb402f34edb91a857cad1fc1c3f84a7b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "cb402f34edb91a857cad1fc1c3f84a7b4a158c797c4620a355976f437c228071"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "484ba0ed9c2dc37bf7e83c42"
# Ciphertext AES (hex): "942f07b8c1dbd4ed28fecfa5d7808d3ef0359d58cf326b752e98925d8532229893a7"
# Tag (hex): "e553c620b95066173aa60f07c45a3ec3"
# Shared Secret Decapsulado (hex): cb402f34edb91a857cad1fc1c3f84a7b4a158c797c4620a355976f437c228071
# Chave AES usada para descriptografar (hex): cb402f34edb91a857cad1fc1c3f84a7b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 29 de 100 ---
# Chave AES usada para criptografar (hex): cbb1e66198a4d137145ec62f65ff83bd
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "cbb1e66198a4d137145ec62f65ff83bde6feafbb01897facc9573f279934cd2b"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "214584e476b3712a7fde1d91"
# Ciphertext AES (hex): "404647816869bf13316e3c92cda6b4affd3c8d0ef61014691982ecf08d11c217f985"
# Tag (hex): "9252c9a96254eb77aefcab2f9a5ea388"
# Shared Secret Decapsulado (hex): cbb1e66198a4d137145ec62f65ff83bde6feafbb01897facc9573f279934cd2b
# Chave AES usada para descriptografar (hex): cbb1e66198a4d137145ec62f65ff83bd
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 30 de 100 ---
# Chave AES usada para criptografar (hex): 29ea15b42bd589e090661a2fb6c9111d
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "29ea15b42bd589e090661a2fb6c9111d64679b2d8ed67e039bbc9c5bfdc78717"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "d76e7d87c8af5f1c346dbf83"
# Ciphertext AES (hex): "8018faa8a51784a2ef42d9619f7c6ba2617093ee1395a136b4b8f89cd844361ceb07"
# Tag (hex): "7431ed1fb9d58ab6685acad05beac5e1"
# Shared Secret Decapsulado (hex): 29ea15b42bd589e090661a2fb6c9111d64679b2d8ed67e039bbc9c5bfdc78717
# Chave AES usada para descriptografar (hex): 29ea15b42bd589e090661a2fb6c9111d
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 31 de 100 ---
# Chave AES usada para criptografar (hex): a8ec8340130fb68459e5118c25474548
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "a8ec8340130fb68459e5118c2547454862b241da593234332242b72f7cf25dfb"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "e619c7cc06054a3f3f8ab85f"
# Ciphertext AES (hex): "3c1e282e4fb507370774c8768b7c80ae10689dc0cd2722fc2067dde461a85967d539"
# Tag (hex): "95ce0f93ca7b21e0f40b0684882c11b4"
# Shared Secret Decapsulado (hex): a8ec8340130fb68459e5118c2547454862b241da593234332242b72f7cf25dfb
# Chave AES usada para descriptografar (hex): a8ec8340130fb68459e5118c25474548
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 32 de 100 ---
# Chave AES usada para criptografar (hex): d44b9fa9da8d8c2a90428eab4ecb5a9b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "d44b9fa9da8d8c2a90428eab4ecb5a9b453389587c649668c1d41a894fa50ec9"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "7c07fcd9330483d0410024d0"
# Ciphertext AES (hex): "299acd10dc814e0a2a08d83e3dbb9437db2609a18ce91beedf83b92e58a6f17f6a87"
# Tag (hex): "f00321cc0aa610df9114adfb22dd688e"
# Shared Secret Decapsulado (hex): d44b9fa9da8d8c2a90428eab4ecb5a9b453389587c649668c1d41a894fa50ec9
# Chave AES usada para descriptografar (hex): d44b9fa9da8d8c2a90428eab4ecb5a9b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 33 de 100 ---
# Chave AES usada para criptografar (hex): 831f831059e750f5b92f3701aebba3d4
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "831f831059e750f5b92f3701aebba3d449b8f8fa24295642a3c60240a24848bf"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "04b2135efdf0935df57f0047"
# Ciphertext AES (hex): "d8a295841970a8d9a257c02c5b116209cfacc4f253d5d685fc67d72268843eeb86cb"
# Tag (hex): "81202fef336a752f8280a3bd38d30c22"
# Shared Secret Decapsulado (hex): 831f831059e750f5b92f3701aebba3d449b8f8fa24295642a3c60240a24848bf
# Chave AES usada para descriptografar (hex): 831f831059e750f5b92f3701aebba3d4
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 34 de 100 ---
# Chave AES usada para criptografar (hex): dfb5dc28ca25a77eb1ab4dffdd0690d9
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "dfb5dc28ca25a77eb1ab4dffdd0690d9e5c2955c6d2009ddc0e094de19bc34f9"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "bf54c854868db7f3cf4adcee"
# Ciphertext AES (hex): "2dcba9a7c0e7fcaed467f8eb2ebc84829f719104c130d7b8b53764754c45dc3524b5"
# Tag (hex): "72863e4ccb0e5a2ef9afd908e90faa9f"
# Shared Secret Decapsulado (hex): dfb5dc28ca25a77eb1ab4dffdd0690d9e5c2955c6d2009ddc0e094de19bc34f9
# Chave AES usada para descriptografar (hex): dfb5dc28ca25a77eb1ab4dffdd0690d9
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 35 de 100 ---
# Chave AES usada para criptografar (hex): 544fbe8b5519fa09d87323aa195cfd69
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "544fbe8b5519fa09d87323aa195cfd69b5ef4987e2b3f9c1fbab6d3bdcef19f2"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "783258cf6d3bc50accb3ce2e"
# Ciphertext AES (hex): "2c263676e189bc48f9ec5f9a7e4375bd253da0947d1459ac7d13a84ba569656bc35a"
# Tag (hex): "877bcee15886db2318b72bc1a4705b58"
# Shared Secret Decapsulado (hex): 544fbe8b5519fa09d87323aa195cfd69b5ef4987e2b3f9c1fbab6d3bdcef19f2
# Chave AES usada para descriptografar (hex): 544fbe8b5519fa09d87323aa195cfd69
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 36 de 100 ---
# Chave AES usada para criptografar (hex): 2a84696ed56375787242e9d505b2ee98
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "2a84696ed56375787242e9d505b2ee98177dacf3f9a0923ad278f59f9fcc7730"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "0b8bbf0b04239a6ab8707c28"
# Ciphertext AES (hex): "409154042f37d4e4ffcdd7bbea90857f05ec29af40acbb7bc6bdfe4a4c6c93d7b327"
# Tag (hex): "037aa525fa7b4a2560899ff7c0ebd14f"
# Shared Secret Decapsulado (hex): 2a84696ed56375787242e9d505b2ee98177dacf3f9a0923ad278f59f9fcc7730
# Chave AES usada para descriptografar (hex): 2a84696ed56375787242e9d505b2ee98
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 37 de 100 ---
# Chave AES usada para criptografar (hex): 241975bdd8d3750cc3694aa5b8a53254
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "241975bdd8d3750cc3694aa5b8a53254bcb621316ce9242046edcd3586763611"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "2b319bc182317c344df32180"
# Ciphertext AES (hex): "07f61219add36a94736302b560d3534f561e46ca961986c656a7a87c0b4aa5cd1d2e"
# Tag (hex): "331a0c2a9e47416b30f14c2e5acf4bdc"
# Shared Secret Decapsulado (hex): 241975bdd8d3750cc3694aa5b8a53254bcb621316ce9242046edcd3586763611
# Chave AES usada para descriptografar (hex): 241975bdd8d3750cc3694aa5b8a53254
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 38 de 100 ---
# Chave AES usada para criptografar (hex): b8b1136c5a8513ea40874c4412287c55
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "b8b1136c5a8513ea40874c4412287c55fc32511667ca1c2b1857e8b8ed274bd1"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "a98396df17c38dc56268bc8a"
# Ciphertext AES (hex): "f65cf59599ab181e84f8c26a35d6242bcba29361d55ff3e4c10af5b4e65cda9a9618"
# Tag (hex): "666a7129b7a2c5e4457107005ce70571"
# Shared Secret Decapsulado (hex): b8b1136c5a8513ea40874c4412287c55fc32511667ca1c2b1857e8b8ed274bd1
# Chave AES usada para descriptografar (hex): b8b1136c5a8513ea40874c4412287c55
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 39 de 100 ---
# Chave AES usada para criptografar (hex): 4faa9798d40169e3d2c4f950f607e1e3
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "4faa9798d40169e3d2c4f950f607e1e392d0e325a3c5b45181a83b765564c219"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "1fa1ea432bbdd22ab5491a86"
# Ciphertext AES (hex): "f8bd513b986948260f9ae3128447d957280b3e408f4aef8ce4e4d504d4790b815b3a"
# Tag (hex): "f84779bd68f9d6a6ae20822fe75140fc"
# Shared Secret Decapsulado (hex): 4faa9798d40169e3d2c4f950f607e1e392d0e325a3c5b45181a83b765564c219
# Chave AES usada para descriptografar (hex): 4faa9798d40169e3d2c4f950f607e1e3
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 40 de 100 ---
# Chave AES usada para criptografar (hex): c3e035fcea8563732691424bf7e3f7a1
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "c3e035fcea8563732691424bf7e3f7a1cdcf35a2a902da42b327222ce393ecdb"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "5fa695504ecf6f373126eb8a"
# Ciphertext AES (hex): "6fdccfc75ffca11246262513b0e5c66f252df118fbe66ec135120defddc567689eee"
# Tag (hex): "ac2493c90c246ab291ad04082ce9b194"
# Shared Secret Decapsulado (hex): c3e035fcea8563732691424bf7e3f7a1cdcf35a2a902da42b327222ce393ecdb
# Chave AES usada para descriptografar (hex): c3e035fcea8563732691424bf7e3f7a1
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 41 de 100 ---
# Chave AES usada para criptografar (hex): 890e045ec18be41ba5855e7e108ce38b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "890e045ec18be41ba5855e7e108ce38ba83e80d29ca204958fd5cfa29294e353"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "abbd02dcc35605509845b4c3"
# Ciphertext AES (hex): "e5e8e332f0c8a1b4a5d71e45e63c71461b64a57f1a4b88c8f992b5c1e48bc68841a5"
# Tag (hex): "2e21489287224e679877dafded6c2348"
# Shared Secret Decapsulado (hex): 890e045ec18be41ba5855e7e108ce38ba83e80d29ca204958fd5cfa29294e353
# Chave AES usada para descriptografar (hex): 890e045ec18be41ba5855e7e108ce38b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 42 de 100 ---
# Chave AES usada para criptografar (hex): ab53c5ae0223e6f21f89e45a35ae3c2a
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "ab53c5ae0223e6f21f89e45a35ae3c2ad2eba745a5420eaa8df69271309cc4e0"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "e59cac62953d15d49bf92779"
# Ciphertext AES (hex): "60c67201b056d9cba1418220c5c62c6c3bc1326e7fb22a9bea3791c39036343cbe90"
# Tag (hex): "7019db769e6ec0b323dc5579872b3f13"
# Shared Secret Decapsulado (hex): ab53c5ae0223e6f21f89e45a35ae3c2ad2eba745a5420eaa8df69271309cc4e0
# Chave AES usada para descriptografar (hex): ab53c5ae0223e6f21f89e45a35ae3c2a
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 43 de 100 ---
# Chave AES usada para criptografar (hex): da617a09c3c434a8669b289de0a0a16e
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "da617a09c3c434a8669b289de0a0a16e39ba6f15f8050002e3dd269701b63392"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "d7295643f10ea179355d23ee"
# Ciphertext AES (hex): "eb63d755150faa10b957864398b26fb723eee309c240bbb6535fd2c27998acbb72f7"
# Tag (hex): "f939963f6ce79cd377f8a47bebc1a007"
# Shared Secret Decapsulado (hex): da617a09c3c434a8669b289de0a0a16e39ba6f15f8050002e3dd269701b63392
# Chave AES usada para descriptografar (hex): da617a09c3c434a8669b289de0a0a16e
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 44 de 100 ---
# Chave AES usada para criptografar (hex): a75aef516da4b62df8b6b9c041b9766b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "a75aef516da4b62df8b6b9c041b9766be95417701e1ccb8ae6faa20be2bcc133"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "48e9265501a7a35a4fd80bf5"
# Ciphertext AES (hex): "34783289d7ac48120e9073917fd9f9d25fba7b41d04c8ed2c8a89c1c69e9dbb8d2d2"
# Tag (hex): "730150cd649f13138a191027f6e302ad"
# Shared Secret Decapsulado (hex): a75aef516da4b62df8b6b9c041b9766be95417701e1ccb8ae6faa20be2bcc133
# Chave AES usada para descriptografar (hex): a75aef516da4b62df8b6b9c041b9766b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 45 de 100 ---
# Chave AES usada para criptografar (hex): 4174be738c0b2ab77d399daa2ef9e066
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "4174be738c0b2ab77d399daa2ef9e066c1796dc1183166b9eb219910505f9ff0"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "68d9f42dddb72225b6507967"
# Ciphertext AES (hex): "1174bf0eef872377dd882b3c65e69ce1eb49a0a81ed09cabd331e16baf0b698921d9"
# Tag (hex): "2790ac52049936a1ebe6334772fcea74"
# Shared Secret Decapsulado (hex): 4174be738c0b2ab77d399daa2ef9e066c1796dc1183166b9eb219910505f9ff0
# Chave AES usada para descriptografar (hex): 4174be738c0b2ab77d399daa2ef9e066
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 46 de 100 ---
# Chave AES usada para criptografar (hex): 54141da6b2844239782d5cc851b11350
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "54141da6b2844239782d5cc851b113500d75826a25d733b9b403ba96ace03760"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "8f78d5846fc2f540e2a4ed30"
# Ciphertext AES (hex): "e9cc32743107768484ee71167e596629bd3a9b1060657487bccfff73360aac12b641"
# Tag (hex): "259658efddd7e9ca9649b4e646d2abb4"
# Shared Secret Decapsulado (hex): 54141da6b2844239782d5cc851b113500d75826a25d733b9b403ba96ace03760
# Chave AES usada para descriptografar (hex): 54141da6b2844239782d5cc851b11350
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 47 de 100 ---
# Chave AES usada para criptografar (hex): 478d3593eeec3a0b347e20d27d2a144b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "478d3593eeec3a0b347e20d27d2a144be74508890d8f1d1670916db92336c830"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "955e406f94e03379c5d5c060"
# Ciphertext AES (hex): "2a91d6d0f61efe35989a2c37b60f5f9ad2ea6e6258fb16cd955bb71a14a49a7882ac"
# Tag (hex): "2b16b3678632fa79fef034739c2916bd"
# Shared Secret Decapsulado (hex): 478d3593eeec3a0b347e20d27d2a144be74508890d8f1d1670916db92336c830
# Chave AES usada para descriptografar (hex): 478d3593eeec3a0b347e20d27d2a144b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 48 de 100 ---
# Chave AES usada para criptografar (hex): 14b79c2a87b813265fc0409914636346
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "14b79c2a87b813265fc040991463634649678de35ff654c9446ab20539566437"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "9a5150ecb1bdf7d797367eb3"
# Ciphertext AES (hex): "8f453d13af99d57124dbd17d456f88e6ca73c78dc5a14d58eb06dca3c6d376d9e7c3"
# Tag (hex): "86e0d9055344e2d6cf2aa6c04fe12583"
# Shared Secret Decapsulado (hex): 14b79c2a87b813265fc040991463634649678de35ff654c9446ab20539566437
# Chave AES usada para descriptografar (hex): 14b79c2a87b813265fc0409914636346
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 49 de 100 ---
# Chave AES usada para criptografar (hex): b4d2a72772472f2ab19e78a7531a4c7f
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "b4d2a72772472f2ab19e78a7531a4c7ff56598e3ac399baba8b3795fcec6ce1c"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "a49120410226f465dbccf917"
# Ciphertext AES (hex): "4310bc208cc03756f2ef76a413e2c2944df509df26871db85f25e40bb0d2e41f6622"
# Tag (hex): "fc9553e23b6fc485bf5a0d3953825410"
# Shared Secret Decapsulado (hex): b4d2a72772472f2ab19e78a7531a4c7ff56598e3ac399baba8b3795fcec6ce1c
# Chave AES usada para descriptografar (hex): b4d2a72772472f2ab19e78a7531a4c7f
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 50 de 100 ---
# Chave AES usada para criptografar (hex): 13944990029fd6391ed5d98a8d1af691
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "13944990029fd6391ed5d98a8d1af69156ca685a7b3e4a10af6dc739674bde2a"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "287ac1ee999cc0d0781bf474"
# Ciphertext AES (hex): "1fe0a5fef06fde13fa3d668cd89d84ddf44dfc79f950d097f7d46b133c7e4002c600"
# Tag (hex): "21e817e4fbaca53c2a37a5fe68a14d0a"
# Shared Secret Decapsulado (hex): 13944990029fd6391ed5d98a8d1af69156ca685a7b3e4a10af6dc739674bde2a
# Chave AES usada para descriptografar (hex): 13944990029fd6391ed5d98a8d1af691
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 51 de 100 ---
# Chave AES usada para criptografar (hex): 288419cf04027219455bc7aa677491fe
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "288419cf04027219455bc7aa677491fe57461b4334192013ec96fce2d1aa8191"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "1877dd62f04b7821c2d11dba"
# Ciphertext AES (hex): "d98dfc22fc1de6492d7a8a8aba4547164a3bf3cda6c85dde4cdd2773297297eaa63c"
# Tag (hex): "307c3ce046d8035312f8ac1dc676b802"
# Shared Secret Decapsulado (hex): 288419cf04027219455bc7aa677491fe57461b4334192013ec96fce2d1aa8191
# Chave AES usada para descriptografar (hex): 288419cf04027219455bc7aa677491fe
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 52 de 100 ---
# Chave AES usada para criptografar (hex): c8814d1c8b782a32200adc1ff5d4de8e
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "c8814d1c8b782a32200adc1ff5d4de8efbed9ff7ec0a1e3a4ba4fdc6225e9ae7"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "010f6195efbbd75154462388"
# Ciphertext AES (hex): "3004a6085489378a8d0ff931d9cc5fb966aaa1ecbbbe6e6017aae768fc92795ef59e"
# Tag (hex): "bd3f4c74a198ff0903bc622526f76cff"
# Shared Secret Decapsulado (hex): c8814d1c8b782a32200adc1ff5d4de8efbed9ff7ec0a1e3a4ba4fdc6225e9ae7
# Chave AES usada para descriptografar (hex): c8814d1c8b782a32200adc1ff5d4de8e
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 53 de 100 ---
# Chave AES usada para criptografar (hex): 133899cf180e28eb189933adfc4795f1
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "133899cf180e28eb189933adfc4795f10efd2e56c5913bd32578a286449f913f"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "e7aa16d2cc74a829c8125daa"
# Ciphertext AES (hex): "556bb46a32d1afa8837028671ee4a8db01d228c19722e4d90dfc41317de9ee8462fd"
# Tag (hex): "2a1cdb2d587a1407d343196facd87223"
# Shared Secret Decapsulado (hex): 133899cf180e28eb189933adfc4795f10efd2e56c5913bd32578a286449f913f
# Chave AES usada para descriptografar (hex): 133899cf180e28eb189933adfc4795f1
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 54 de 100 ---
# Chave AES usada para criptografar (hex): fa53617e2945cce4e77c5399d32f4103
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "fa53617e2945cce4e77c5399d32f41033201d8e7e56f14bbac1284cf3987d0e7"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "5b07ef5fd28f00da9c5cb046"
# Ciphertext AES (hex): "8b26fd8d0e807199b560bf2cd2e404c43b16c0f7bb85b07cb34994306fa3d2ade7e2"
# Tag (hex): "223df1b5c29c8038e701857dc89a3046"
# Shared Secret Decapsulado (hex): fa53617e2945cce4e77c5399d32f41033201d8e7e56f14bbac1284cf3987d0e7
# Chave AES usada para descriptografar (hex): fa53617e2945cce4e77c5399d32f4103
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 55 de 100 ---
# Chave AES usada para criptografar (hex): edd7edbf8edfdd55a066d35ea256106b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "edd7edbf8edfdd55a066d35ea256106b2be02d2f6ad354429b1f7b7135f55cbf"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "866f10839d58bf82a3382c64"
# Ciphertext AES (hex): "949970af5ffc06885cc6ef2c38782de6c4297460f9fd5839ce126ced27b5cbe22725"
# Tag (hex): "7f6184f089cea977accc7c7cd513c4bc"
# Shared Secret Decapsulado (hex): edd7edbf8edfdd55a066d35ea256106b2be02d2f6ad354429b1f7b7135f55cbf
# Chave AES usada para descriptografar (hex): edd7edbf8edfdd55a066d35ea256106b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 56 de 100 ---
# Chave AES usada para criptografar (hex): 320b5eb9900602147d8e910e81da22b0
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "320b5eb9900602147d8e910e81da22b089381481bf37f4746f82bc83fc4313fd"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "b0e786ba806b6f03ad2d6afd"
# Ciphertext AES (hex): "9211de459c374a5dbef360a03aafedc6a551638613ce5538f7119b92a7e92951021c"
# Tag (hex): "9f857690b83299372d9ed5aab444c47d"
# Shared Secret Decapsulado (hex): 320b5eb9900602147d8e910e81da22b089381481bf37f4746f82bc83fc4313fd
# Chave AES usada para descriptografar (hex): 320b5eb9900602147d8e910e81da22b0
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 57 de 100 ---
# Chave AES usada para criptografar (hex): af31d3d28d21108e3021c7110821cf5d
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "af31d3d28d21108e3021c7110821cf5d652dde6e76551bf82b1440628b71b60f"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "92a58b91d38ee3d68c4c9f24"
# Ciphertext AES (hex): "3aad673627b76acdbc32c6d54af8b00631b947454893fa397b74dd6c026e64e38487"
# Tag (hex): "378f6a55e349a159c195f594db0093e3"
# Shared Secret Decapsulado (hex): af31d3d28d21108e3021c7110821cf5d652dde6e76551bf82b1440628b71b60f
# Chave AES usada para descriptografar (hex): af31d3d28d21108e3021c7110821cf5d
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 58 de 100 ---
# Chave AES usada para criptografar (hex): ab08def08e4a97dd6f2fef3d7ffb937c
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "ab08def08e4a97dd6f2fef3d7ffb937c95730121e89a8fc11584a95c32f941a6"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "28498c4f7f1118c8cf81f123"
# Ciphertext AES (hex): "3a7788946b70e4adab605d904e1460a8310beecf55e22b097e7b554cc43ed34424b7"
# Tag (hex): "2ba29fe0c9ed0c04b0bf0e8422464401"
# Shared Secret Decapsulado (hex): ab08def08e4a97dd6f2fef3d7ffb937c95730121e89a8fc11584a95c32f941a6
# Chave AES usada para descriptografar (hex): ab08def08e4a97dd6f2fef3d7ffb937c
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 59 de 100 ---
# Chave AES usada para criptografar (hex): 1eb4e1d164e14d81b043d0a2968fe2fc
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "1eb4e1d164e14d81b043d0a2968fe2fc233a899f9a856100401492757c9d2de2"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "993daf81aa5d73ced88fdce0"
# Ciphertext AES (hex): "ed29399740610e212458c99108d8a9beaa27e252c4d49d14e13ca1cd83a771c98310"
# Tag (hex): "9a915cf9a83ede08867e66bc3858a0a5"
# Shared Secret Decapsulado (hex): 1eb4e1d164e14d81b043d0a2968fe2fc233a899f9a856100401492757c9d2de2
# Chave AES usada para descriptografar (hex): 1eb4e1d164e14d81b043d0a2968fe2fc
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 60 de 100 ---
# Chave AES usada para criptografar (hex): 88dbd5fcbaa555d0e17a7bc8601510e9
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "88dbd5fcbaa555d0e17a7bc8601510e9c68969b4207c17e31ad42c694128d537"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "99504b17a9f41847f9599fa9"
# Ciphertext AES (hex): "63ecbb864b4f95ccd5f9b1d918c08cdab1bf9c8354ce52415269b7d42b0c707b12b2"
# Tag (hex): "d5444dc2a9d72ba271b171d5e0a9146b"
# Shared Secret Decapsulado (hex): 88dbd5fcbaa555d0e17a7bc8601510e9c68969b4207c17e31ad42c694128d537
# Chave AES usada para descriptografar (hex): 88dbd5fcbaa555d0e17a7bc8601510e9
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 61 de 100 ---
# Chave AES usada para criptografar (hex): 56bcc70ca0c7a8e50cc3a62a42059282
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "56bcc70ca0c7a8e50cc3a62a420592821c32686fc49556d066d83166e7177471"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "8c5e398e770a20e8ad0581c7"
# Ciphertext AES (hex): "51cbe3b6c6eeae62ea891095504aebe4adbc347f6aff0e6a543878561392a55338be"
# Tag (hex): "3103f23f21fc1fa17b57cf100d4c1eb1"
# Shared Secret Decapsulado (hex): 56bcc70ca0c7a8e50cc3a62a420592821c32686fc49556d066d83166e7177471
# Chave AES usada para descriptografar (hex): 56bcc70ca0c7a8e50cc3a62a42059282
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 62 de 100 ---
# Chave AES usada para criptografar (hex): 54e1bde62dccd974532685931287e718
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "54e1bde62dccd974532685931287e7187d6644774430dde6177c33a317de09fb"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "1da64cb07ec5b9167a4db88d"
# Ciphertext AES (hex): "a7b792856c47ad063a3f711ccd9e60fb7a45786b95a17336cc4d3ee32cd652f90cf6"
# Tag (hex): "f4e6dbed07b0c5f0c83786231d3cbd0a"
# Shared Secret Decapsulado (hex): 54e1bde62dccd974532685931287e7187d6644774430dde6177c33a317de09fb
# Chave AES usada para descriptografar (hex): 54e1bde62dccd974532685931287e718
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 63 de 100 ---
# Chave AES usada para criptografar (hex): 0cf4417f3d921995bef615175cf56297
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "0cf4417f3d921995bef615175cf56297e519ae3cb690bc595e7a0f8644c4cd90"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "d4fa46308605ec5a4255d648"
# Ciphertext AES (hex): "5f2a66ab92c4e0cb046c5185742ee73f35ccaabf83522286a043bf7f13a2d5521436"
# Tag (hex): "d4780bb12a3c35b41e2f85f2321e5a99"
# Shared Secret Decapsulado (hex): 0cf4417f3d921995bef615175cf56297e519ae3cb690bc595e7a0f8644c4cd90
# Chave AES usada para descriptografar (hex): 0cf4417f3d921995bef615175cf56297
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 64 de 100 ---
# Chave AES usada para criptografar (hex): 8501124cf6ee590ee454ea2cdf5ae9a1
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# ...
#
# --- Iteração 80 de 100 ---
# Chave AES usada para criptografar (hex): 2ee36f497872c8b2e25fa57933db5278
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "2ee36f497872c8b2e25fa57933db527838af9b44bcaa543f4a3034d1d05093e2"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "4a2712951609b0c3e4211586"
# Ciphertext AES (hex): "b65060969edc8530843d0182438cce3ddc966f9b1a0e85a41eb1b419c23f47bafe99"
# Tag (hex): "8a97beed334e4a4c5dc1aad99e39a79e"
# Shared Secret Decapsulado (hex): 2ee36f497872c8b2e25fa57933db527838af9b44bcaa543f4a3034d1d05093e2
# Chave AES usada para descriptografar (hex): 2ee36f497872c8b2e25fa57933db5278
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 81 de 100 ---
# Chave AES usada para criptografar (hex): 33a58837b8f51454c5fb6611007085d7
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "33a58837b8f51454c5fb6611007085d7894de342bdf9c0d19451ff880f68c420"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "5f0a8e96f14f703e0440e0c4"
# Ciphertext AES (hex): "bad3e7577e1bdf220e3dc724530cd52bd4babcebf86010d3b51db7b14726af68b260"
# Tag (hex): "737be98851c6f2b5e860239609e8c94e"
# Shared Secret Decapsulado (hex): 33a58837b8f51454c5fb6611007085d7894de342bdf9c0d19451ff880f68c420
# Chave AES usada para descriptografar (hex): 33a58837b8f51454c5fb6611007085d7
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 82 de 100 ---
# Chave AES usada para criptografar (hex): e1a1d76e04682ba761e99fb771ebc284
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "e1a1d76e04682ba761e99fb771ebc284bd812508c1cfa6edcdea4799524e05d2"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "7b0702f84e5a2bcda7b1fa83"
# Ciphertext AES (hex): "85445403ecaece702c5f8180aa7fa4f4e39b08695794f5d70c2b7a238399f5e5a3e7"
# Tag (hex): "9edc904379f1160a025f65a69824dcb2"
# Shared Secret Decapsulado (hex): e1a1d76e04682ba761e99fb771ebc284bd812508c1cfa6edcdea4799524e05d2
# Chave AES usada para descriptografar (hex): e1a1d76e04682ba761e99fb771ebc284
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 83 de 100 ---
# Chave AES usada para criptografar (hex): 5d87012931139bf5c97eded68f3e6e0d
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "5d87012931139bf5c97eded68f3e6e0db667a5d5e3e81bc315bf5c3af2c7f5e0"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "a91ede1b09c26056e0abf656"
# Ciphertext AES (hex): "2817d1256c8c3b419b3ff23baab71f7d12253a2bc296eac9e4343927f757cf01883b"
# Tag (hex): "1796edbdba1a8c92308eb2ebd3c9f5af"
# Shared Secret Decapsulado (hex): 5d87012931139bf5c97eded68f3e6e0db667a5d5e3e81bc315bf5c3af2c7f5e0
# Chave AES usada para descriptografar (hex): 5d87012931139bf5c97eded68f3e6e0d
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 84 de 100 ---
# Chave AES usada para criptografar (hex): 437bf35a81491b91d95aeb8e89a33acd
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "437bf35a81491b91d95aeb8e89a33acdddbbce7b5b82b6732a74283900cd726c"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "ec57e47543c30388e803584e"
# Ciphertext AES (hex): "e82a9579c3db17cac7d0a1fc0c5606844ee029001672d5fcd39892b4ed039d91600d"
# Tag (hex): "4c9a2b8c5c259c9de0c5be0d3755ab69"
# Shared Secret Decapsulado (hex): 437bf35a81491b91d95aeb8e89a33acdddbbce7b5b82b6732a74283900cd726c
# Chave AES usada para descriptografar (hex): 437bf35a81491b91d95aeb8e89a33acd
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 85 de 100 ---
# Chave AES usada para criptografar (hex): 53eca12575368c0d202a5458202c5392
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "53eca12575368c0d202a5458202c5392fafa68c0cf97500408225431bcdc18ee"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "8998f195134ecf6df38272db"
# Ciphertext AES (hex): "27373a219e907bca95d615dd6b55719833dedf1f0d7932dde2b1c95aa7baf2daea93"
# Tag (hex): "3e57fbcc0ebf1651165e521881c10407"
# Shared Secret Decapsulado (hex): 53eca12575368c0d202a5458202c5392fafa68c0cf97500408225431bcdc18ee
# Chave AES usada para descriptografar (hex): 53eca12575368c0d202a5458202c5392
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 86 de 100 ---
# Chave AES usada para criptografar (hex): b9b9eb01d095128e9bcf19de29314c04
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "b9b9eb01d095128e9bcf19de29314c041adc48d52dd290ae656fad8ada219ce5"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "98e8794fdae55d56ad12b0cb"
# Ciphertext AES (hex): "69d969b8b9865c82fb47da877851eb4368d402830d0dcf33e1371dcfe940d21aa66d"
# Tag (hex): "49943a33308c1497044a6192a8946139"
# Shared Secret Decapsulado (hex): b9b9eb01d095128e9bcf19de29314c041adc48d52dd290ae656fad8ada219ce5
# Chave AES usada para descriptografar (hex): b9b9eb01d095128e9bcf19de29314c04
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 87 de 100 ---
# Chave AES usada para criptografar (hex): 2cb23d854c1a36845548394edb8ec13b
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "2cb23d854c1a36845548394edb8ec13b148135ca9d882fa3e180312eda7405ac"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "fb0b2dbb5a8917f30a7105dc"
# Ciphertext AES (hex): "74df1587e400042bbcb7881d305cee87e33e0826a0c3063091011d88fea4eb42c137"
# Tag (hex): "4dd077afeed2972b64516f7fd9c33f92"
# Shared Secret Decapsulado (hex): 2cb23d854c1a36845548394edb8ec13b148135ca9d882fa3e180312eda7405ac
# Chave AES usada para descriptografar (hex): 2cb23d854c1a36845548394edb8ec13b
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 88 de 100 ---
# Chave AES usada para criptografar (hex): c859e4da02495e5c5b96481416fab261
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "c859e4da02495e5c5b96481416fab261ae9094d12cf4ab4b4a89dc054b142e55"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "8bd37caad6dd5f7cb128b2f9"
# Ciphertext AES (hex): "6abdfb3bc958f14ef92c81604ad0c73eae2631f1c6c0251f7e963e097bb3bbffeca1"
# Tag (hex): "ef2249a3fabc3cd7985854a7b57963b5"
# Shared Secret Decapsulado (hex): c859e4da02495e5c5b96481416fab261ae9094d12cf4ab4b4a89dc054b142e55
# Chave AES usada para descriptografar (hex): c859e4da02495e5c5b96481416fab261
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 89 de 100 ---
# Chave AES usada para criptografar (hex): 5edff02bf4b5e459f833b97ec07335e4
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "5edff02bf4b5e459f833b97ec07335e4ad7a75096f675103cafa6a7ff7b3be4a"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "616fc951867e2f6813754733"
# Ciphertext AES (hex): "419e555b8b08af59f1630572955ae47eb95d749adaafee2bd340ad30eb0c10965ee6"
# Tag (hex): "9a76f2553bc2358d3258f2ee66f7b18d"
# Shared Secret Decapsulado (hex): 5edff02bf4b5e459f833b97ec07335e4ad7a75096f675103cafa6a7ff7b3be4a
# Chave AES usada para descriptografar (hex): 5edff02bf4b5e459f833b97ec07335e4
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 90 de 100 ---
# Chave AES usada para criptografar (hex): 3f6d0fcf895692f9217d6d6eaa834d23
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "3f6d0fcf895692f9217d6d6eaa834d23e334ec01e91e22268da517f843458e76"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "e279bcde6086993daa00b431"
# Ciphertext AES (hex): "f959b9fb9ad40587374f786bc8020c988b9f0aeaa0e4b528b0c76f7a645991113783"
# Tag (hex): "bcfa77b155b7773a41d98b9c2b5cd8f7"
# Shared Secret Decapsulado (hex): 3f6d0fcf895692f9217d6d6eaa834d23e334ec01e91e22268da517f843458e76
# Chave AES usada para descriptografar (hex): 3f6d0fcf895692f9217d6d6eaa834d23
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 91 de 100 ---
# Chave AES usada para criptografar (hex): 842e4f90bff6a0c9e3dcfd6163a87a7c
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "842e4f90bff6a0c9e3dcfd6163a87a7c9c30068e946cc09c5e66ef409af8a98b"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "ad05c62e511186d087577f5f"
# Ciphertext AES (hex): "100b48f27051d888ff93ceb0368e3fc4fd6b406c44437cd0d124e343e07eccee2545"
# Tag (hex): "f76e4c14a2a227a5983f508c0d7f0b4e"
# Shared Secret Decapsulado (hex): 842e4f90bff6a0c9e3dcfd6163a87a7c9c30068e946cc09c5e66ef409af8a98b
# Chave AES usada para descriptografar (hex): 842e4f90bff6a0c9e3dcfd6163a87a7c
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 92 de 100 ---
# Chave AES usada para criptografar (hex): bb93519e076147ee2520157ea9048505
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "bb93519e076147ee2520157ea90485056d47587e05baef1f0336bceb7856ad1c"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "2bdfbbce57ae92650f7cc380"
# Ciphertext AES (hex): "4835e644dff5077ab7e08b31948601e7b32b7a293177c414c9c4f48304c08420b122"
# Tag (hex): "d498d73190f1f2ab1fa82fa37c3e934a"
# Shared Secret Decapsulado (hex): bb93519e076147ee2520157ea90485056d47587e05baef1f0336bceb7856ad1c
# Chave AES usada para descriptografar (hex): bb93519e076147ee2520157ea9048505
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 93 de 100 ---
# Chave AES usada para criptografar (hex): fe4356b9c69630c0302670da6bb57279
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "fe4356b9c69630c0302670da6bb572793890f0f4b5a209245f682f6d76927a23"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "bab8242c7308d6db195961e9"
# Ciphertext AES (hex): "a7133739ad5a94343cb0aa9037a7d23334374cc97d21c15d76349d66a0e20b4825a8"
# Tag (hex): "0c3121fb83a5e90c140ce63f6c462a8c"
# Shared Secret Decapsulado (hex): fe4356b9c69630c0302670da6bb572793890f0f4b5a209245f682f6d76927a23
# Chave AES usada para descriptografar (hex): fe4356b9c69630c0302670da6bb57279
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 94 de 100 ---
# Chave AES usada para criptografar (hex): 55f5a2f8614c759cbf54b81164e1dff7
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "55f5a2f8614c759cbf54b81164e1dff790d785023cb862d750d924255ccefa77"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "3aa3c03d753e27d2079e1930"
# Ciphertext AES (hex): "8a70c436b42de50d7f893ffd695bdb52c13836a70f295f2a6755f2e21c6689cf56b7"
# Tag (hex): "9e366359899f1ca1e29f696b546ea0f6"
# Shared Secret Decapsulado (hex): 55f5a2f8614c759cbf54b81164e1dff790d785023cb862d750d924255ccefa77
# Chave AES usada para descriptografar (hex): 55f5a2f8614c759cbf54b81164e1dff7
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 95 de 100 ---
# Chave AES usada para criptografar (hex): 22c3ab03570a49bf0fccc2673f7f88ac
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "22c3ab03570a49bf0fccc2673f7f88acdd5cf328d05286198359e9bd183fb649"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "ffaf627bc36ef8dd20c8f51c"
# Ciphertext AES (hex): "196442bbef9ade618ac29a2248ceb52b85441122078a0f8b004301e41a367105edbe"
# Tag (hex): "f47e49cd6142d57709587604ea75bdf7"
# Shared Secret Decapsulado (hex): 22c3ab03570a49bf0fccc2673f7f88acdd5cf328d05286198359e9bd183fb649
# Chave AES usada para descriptografar (hex): 22c3ab03570a49bf0fccc2673f7f88ac
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 96 de 100 ---
# Chave AES usada para criptografar (hex): 6247580ad836a15cd52e5e89bb3d9283
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "6247580ad836a15cd52e5e89bb3d92836f118b3dc41cca0846dd4dc2438e2c3a"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "87bb9cb965242aa4ed594cc0"
# Ciphertext AES (hex): "78369cbc54104c388300dd1de80ab7463b7ce5fa5a6d48b47be2d954030ad7f18320"
# Tag (hex): "367d45acd3c39e42cbffbd12a5d18537"
# Shared Secret Decapsulado (hex): 6247580ad836a15cd52e5e89bb3d92836f118b3dc41cca0846dd4dc2438e2c3a
# Chave AES usada para descriptografar (hex): 6247580ad836a15cd52e5e89bb3d9283
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 97 de 100 ---
# Chave AES usada para criptografar (hex): e5834a77bb6ca0880f627734ff85d4ca
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "e5834a77bb6ca0880f627734ff85d4cae3cb5d4a47d471a629b81b2f68bf8ef6"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "0c46761c024a50e196a4b6a5"
# Ciphertext AES (hex): "a5ad47a2ca7e916a11c0203524b744deb4c8ea97d9b347e97a041e01063ede18ddb1"
# Tag (hex): "27f092ab8af1cb378613523aea10e0cf"
# Shared Secret Decapsulado (hex): e5834a77bb6ca0880f627734ff85d4cae3cb5d4a47d471a629b81b2f68bf8ef6
# Chave AES usada para descriptografar (hex): e5834a77bb6ca0880f627734ff85d4ca
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 98 de 100 ---
# Chave AES usada para criptografar (hex): c41077ab6af0cf3a73a9a97b503e33d5
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "c41077ab6af0cf3a73a9a97b503e33d573a5cbcb71a4b804f20c04c8b9b5682d"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "a364d0f9c8596da0543b9b1e"
# Ciphertext AES (hex): "e318a2a536152314a4de99ac4b6039a0ae6dd35e76bd78ec1186125b19b58f240e93"
# Tag (hex): "e74ef94d91187355ad4a36cdb31fbd78"
# Shared Secret Decapsulado (hex): c41077ab6af0cf3a73a9a97b503e33d573a5cbcb71a4b804f20c04c8b9b5682d
# Chave AES usada para descriptografar (hex): c41077ab6af0cf3a73a9a97b503e33d5
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 99 de 100 ---
# Chave AES usada para criptografar (hex): 35ab0d167b664754d3d56e806447347a
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "35ab0d167b664754d3d56e806447347a18faaff3955f2dc8af8d34d46aacfc94"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "c975ff55e229fd63c205c2bf"
# Ciphertext AES (hex): "ff557a35e06c1171ab9e3daf1e474404d213a74999973ec8647693bc92348f244a15"
# Tag (hex): "4d93b1ab96747788444af65b3a6f1156"
# Shared Secret Decapsulado (hex): 35ab0d167b664754d3d56e806447347a18faaff3955f2dc8af8d34d46aacfc94
# Chave AES usada para descriptografar (hex): 35ab0d167b664754d3d56e806447347a
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# --- Iteração 100 de 100 ---
# Chave AES usada para criptografar (hex): a33d69e328286a9313a2bcffd863feb4
#
# ===== Criptografia Completa =====
# Private Key (hex): "..."
# Public Key (hex): "..."
# Shared Secret (hex): "a33d69e328286a9313a2bcffd863feb4fbc1f76a7b032fd5f5f14449feac05e4"
# Ciphertext KEM (hex): "..."
# Nonce (hex): "a10bb1007a91f1a79d3f6108"
# Ciphertext AES (hex): "1e6bac41f2a3b2bad83653a49011014ab06adf6a9bb6fb5fa6ab6da9257d00c1928d"
# Tag (hex): "648d274f4b5e92a9fb7d3df8f52c45a8"
# Shared Secret Decapsulado (hex): a33d69e328286a9313a2bcffd863feb4fbc1f76a7b032fd5f5f14449feac05e4
# Chave AES usada para descriptografar (hex): a33d69e328286a9313a2bcffd863feb4
#
# ===== Descriptografia Completa =====
# Texto descriptografado: Teste de implementação Kyber IME
#
# ===== Análise Final =====
# Tempo total: 4.7408 segundos
# Consumo máximo de CPU: 26.0375%
# Consumo máximo de Memória: 0.0938 MiB
# Média de consumo de CPU: 8.9644%
# Média de consumo de Memória: -0.0003 MiB
